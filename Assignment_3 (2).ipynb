# %% [markdown]
# ## Final Assignment Overview: Working with Patient Records and Encounter Notes
#
# In this final assignment, we’ll focus on patient records related to COVID-19 encounters. Our task is to analyze, process, and transform the data while applying the concepts we’ve covered throughout this course. Here's a detailed breakdown of the assignment:
#
# What Are Encounter Notes?
# An encounter note is a record that captures details about a patient’s visit with a doctor. It includes both structured and semi-structured information that is crucial for understanding the context of the visit. Here’s what an encounter note typically looks like:
#
# ```
# AMBULATORY ENCOUNTER NOTE
# Date of Service: March 2, 2020 15:45-16:30
#
# DEMOGRAPHICS:
# Name: Jeffrey Greenfelder
# DOB: 1/16/2005
# Gender: Male
# Address: 428 Wiza Glen Unit 91, Springfield, Massachusetts 01104
# Insurance: Guardian
# MRN: 055ae6fc-7e18-4a39-8058-64082ca6d515
#
# PERTINENT MEDICAL HISTORY:
# - Obesity
#
# Recent Visit: Well child visit (2/23/2020)
# Immunizations: Influenza vaccine (2/23/2020)
#
# Recent Baseline (2/23/2020):
# Height: 155.0 cm
# Weight: 81.2 kg
# BMI: 33.8 kg/m² (99.1th percentile)
# BP: 123/80 mmHg
# HR: 92/min
# RR: 13/min
#
# SUBJECTIVE:
# Adolescent patient presents with multiple symptoms including:
# - Cough
# - Sore throat
# - Severe fatigue
# - Muscle pain
# - Joint pain
# - Fever
# Never smoker. Symptoms began recently.
#
# OBJECTIVE:
# Vitals:
# Temperature: 39.3°C (102.7°F)
# Heart Rate: 131.1/min
# Blood Pressure: 120/73 mmHg
# Respiratory Rate: 27.6/min
# O2 Saturation: 75.8% on room air
# Weight: 81.2 kg
#
# Laboratory/Testing:
# Comprehensive Respiratory Panel:
# - Influenza A RNA: Negative
# - Influenza B RNA: Negative
# - RSV RNA: Negative
# - Parainfluenza virus 1,2,3 RNA: Negative
# - Rhinovirus RNA: Negative
# - Human metapneumovirus RNA: Negative
# - Adenovirus DNA: Negative
# - SARS-CoV-2 RNA: Positive
#
# ASSESSMENT:
# 1. Suspected COVID-19 with severe symptoms
# 2. Severe hypoxemia requiring immediate intervention
# 3. Tachycardia (HR 131)
# 4. High-grade fever
# 5. Risk factors:
#    - Obesity (BMI 33.8)
#    - Adolescent age
#
# PLAN:
# 1. Face mask provided for immediate oxygen support
# 2. Infectious disease care plan initiated
# 3. Close monitoring required due to:
#    - Severe hypoxemia
#    - Tachycardia
#    - Age and obesity risk factors
# 4. Parent/patient education on:
#    - Home isolation protocols
#    - Warning signs requiring emergency care
#    - Return precautions
# 5. Follow-up plan:
#    - Daily monitoring during acute phase
#    - Virtual check-ins as needed
#
# Encounter Duration: 45 minutes
# Encounter Type: Ambulatory
# Provider: ID# e2c226c2-3e1e-3d0b-b997-ce9544c10528
# Facility: 5103c940-0c08-392f-95cd-446e0cea042a
# ```
#
#
# The enocuter contains
#
# * General encounter information:
#
#   * When the encounter took place: Date and time of the visit.
#   * Demographics: Patient’s age, gender, and unique medical record identifier.
#   * Encounter details: The reason for the visit, diagnosis, and any associated costs.
#
#
# * Semi-Structured Notes:
#
# These notes mirror how doctors organize their thoughts and observations during an encounter. They generally follow a SOAP format:
#
# * Subjective: The patient’s subjective description of their symptoms, feelings, and medical concerns.
# * Objective: The doctor’s objective findings, including test results, measurements, or physical examination outcomes.
# * Assessment: The doctor’s evaluation or diagnosis based on subjective and objective information.
# * Plan: The proposed treatment plan, including medications, follow-ups, or other interventions.
#
# While some encounter notes might include additional details, the majority conform to this semi-structured format, making them ideal for analysis and transformation.
#
# * Goals for the Assignment
#
# 1. Transforming Encounter Notes:
#
# Using an LLM to convert semi-structured encounter notes into a JSON format that organizes the information into structured fields. The JSON will include details such as demographics, encounter specifics, and the SOAP components of the note. Subsequently, you will need to transform the JSON data into a Parquet file, which is not only suitable for analysis in Spark but also ideal for storage later.
# Here we will use the ML classificaition to assing the objective and assessment semi-structured fields into standardized, structured fields. The medical taxonomy for this task will be the one provided by the CDC, which defines standard codes for diagnoses, symptoms, procedures, and treatments. This step ensures the structured data aligns with domain-wide medical standards, making it interoperable and ready for deeper analysis.
#
# The JSON format should capture the hierachies described in the structure below.
#
#
#
#
# 2. Basic Analytics and Visualizations:
# Using Apache Spark, perform comprehensive data analysis on the encounter data and create visualizations that reveal meaningful patterns. Your analysis must include:
# - COVID-19 Case Demographics: Case breakdown by age ranges ([0-5], [6-10], [11-17], [18-30], [31-50], [51-70], [71+])
# - Cumulative case count of Covid between the earliest case observed in the dataset and last case observed
# - Symptoms for all COVID-19 patients versus patients that admitted into the intensive care unit due to COVID.
# - Rank medications by frequency of prescription
# - Analyze medication patterns across different demographic groups (e.g., top 3 per age group)
# - Identify and plot co-morbidity information from the patient records (e.g., hypertension, obesity, prediabetes, etc.) provided in the dataset.
# - An independent group analysis: You need to develop and execute THREE original analyses that provide meaningful insights about COVID-19 patterns in this dataset. For each analysis:
#   - Clearly state your analytical question/hypothesis
#   - Justify why this analysis is valuable
#   - Show your Spark code and methodology
#   - Present results with appropriate visualizations

# %% [markdown]
# # JSON HIERARCHIES
# ```
# EncounterType:
#     code
#     description
#
# Encounter:
#     id
#     date
#     time
#     type: EncounterType
#     provider_id
#     facility_id
#
# Address:
#     city
#     state
#
# Demographics:
#     id
#     name
#     date_of_birth
#     age
#     gender
#     address: Address
#     insurance
#
# Condition:
#     code
#     description
#
# Medication:
#     code
#     description
#
# Immunization:
#     code
#     description
#     date: date
#
# VitalMeasurement:
#     code
#     value: float
#     unit
#
# BloodPressure:
#     systolic: VitalMeasurement
#     diastolic: VitalMeasurement
#
# CurrentVitals:
#     temperature: VitalMeasurement
#     heart_rate: VitalMeasurement
#     blood_pressure: BloodPressure
#     respiratory_rate: VitalMeasurement
#     oxygen_saturation: VitalMeasurement
#     weight: VitalMeasurement
#
# BaselineVitals:
#     date: date
#     height: VitalMeasurement
#     weight: VitalMeasurement
#     bmi: VitalMeasurement
#     bmi_percentile: VitalMeasurement
#
# Vitals:
#     current: CurrentVitals
#     baseline: BaselineVitals
#
# RespiratoryTest:
#     code
#     result
#
# RespiratoryPanel:
#     influenza_a: RespiratoryTest
#     influenza_b: RespiratoryTest
#     rsv: RespiratoryTest
#     parainfluenza_1: RespiratoryTest
#     parainfluenza_2: RespiratoryTest
#     parainfluenza_3: RespiratoryTest
#     rhinovirus: RespiratoryTest
#     metapneumovirus: RespiratoryTest
#     adenovirus: RespiratoryTest
#
# Covid19Test:
#     code
#     description
#     result
#
# Laboratory:
#     covid19: Covid19Test
#     respiratory_panel: RespiratoryPanel
#
# Procedure:
#     code
#     description
#     date: date
#     reasonCode
#     reasonDescription
#
# CarePlan:
#     id
#     code
#     description
#     start: date
#     stop: date
#     reasonCode
#     reasonDescription
#
# PatientRecord:
#     encounter: Encounter
#     demographics: Demographics
#     conditions: List[Condition]
#     medications: List[Medication]
#     immunizations: List[Immunization]
#     vitals: Vitals
#     laboratory: Laboratory
#     procedures: List[Procedure]
#
#
#
#
# class Address(BaseModel):
#     city: str = Field(description=" the city where the patient lives. Should be under DEMOGRAPHICS header")
#     state: str
#
# class Demographics(BaseModel):
#     name: str
#     date_of_birth: str
#     age: int
#     gender: str
#     address: Address
#     insurance: str
#
# class Medication(BaseModel):
#     code: str
#     description: str
#
# class PatientRecord(BaseModel):
#     demographics: Demographics
#     medications: List[Medication]
#
#
# llm = ChatOpenAI(model="gpt-4o-mini")
# structured_llm = llm.with_structured_output(PatientRecord)
#
# structured_llm.invoke(PATIENT_NOTE)

# %%
!-m pip install --upgrade pip
# Out:
# /bin/bash: - : invalid option
# Usage:	/bin/bash [GNU long option] [option] ...
# 	/bin/bash [GNU long option] [option] script-file ...
# GNU long options:
# 	--debug
# 	--debugger
# 	--dump-po-strings
# 	--dump-strings
# 	--help
# 	--init-file
# 	--login
# 	--noediting
# 	--noprofile
# 	--norc
# 	--posix
# 	--pretty-print
# 	--rcfile
# 	--restricted
# 	--verbose
# 	--version
# Shell options:
# 	-ilrsD or -c command or -O shopt_option		(invocation only)
# 	-abefhkmnptuvxBCHP or -o option

# %%
# !pip install -U sentence-transformers
# !pip install faiss-cpu
# !pip install PyMuPDF Pillow numpy
# Out:
# Collecting sentence-transformers
#   Obtaining dependency information for sentence-transformers from https://files.pythonhosted.org/packages/8b/c8/990e22a465e4771338da434d799578865d6d7ef1fdb50bd844b7ecdcfa19/sentence_transformers-3.3.1-py3-none-any.whl.metadata
#   Downloading sentence_transformers-3.3.1-py3-none-any.whl.metadata (10 kB)
# Collecting transformers<5.0.0,>=4.41.0 (from sentence-transformers)
#   Obtaining dependency information for transformers<5.0.0,>=4.41.0 from https://files.pythonhosted.org/packages/d0/a7/7eedcf6a359e1e1eff3bc204ad022485aa5d88c08e1e3e0e0aee8a2e2235/transformers-4.47.0-py3-none-any.whl.metadata
#   Downloading transformers-4.47.0-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/43.5 kB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 3.0 MB/s eta 0:00:00
# Collecting tqdm (from sentence-transformers)
#   Obtaining dependency information for tqdm from https://files.pythonhosted.org/packages/d0/30/dc54f88dd4a2b5dc8a0279bdd7270e735851848b762aeb1c1184ed1f6b14/tqdm-4.67.1-py3-none-any.whl.metadata
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/57.7 kB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 4.7 MB/s eta 0:00:00
# Collecting torch>=1.11.0 (from sentence-transformers)
#   
vidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11.0->sentence-transformers)
#   Obtaining dependency information for nvidia-cusparse-cu12==12.3.1.170 from https://files.pythonhosted.org/packages/db/f7/97a9ea26ed4bbbfc2d470994b8b4f338ef663be97b8f677519ac195e113d/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch>=1.11.0->sentence-transformers)
#   Obtaining dependency information for nvidia-nccl-cu12==2.21.5 from https://files.pythonhosted.org/packages/df/99/12cd266d6233f47d00daf3a72739872bdc10267d0383508b0b9c84a18bb6/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Obtaining dependency information for nvidia-nvtx-cu12==12.4.127 from https://files.pythonhosted.org/packages/87/20/199b8713428322a2f22b722c62b8cc278cc53dffa9705d744484b5035ee9/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Obtaining dependency information for nvidia-nvjitlink-cu12==12.4.127 from https://files.pythonhosted.org/packages/ff/ff/847841bacfbefc97a00036e0fce5a0f086b640756dc38caea5e1bb002655/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.1.0 (from torch>=1.11.0->sentence-transformers)
#   Obtaining dependency information for triton==3.1.0 from https://files.pythonhosted.org/packages/86/17/d9a5cf4fcf46291856d1e90762e36cbabd2a56c7265da0d1d9508c8e3943/triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting sympy==1.13.1 (from torch>=1.11.0->sentence-transformers)
#   Obtaining dependency information for sympy==1.13.1 from https://files.pythonhosted.org/packages/b2/fe/81695a1aa331a842b582453b605175f419fe8540355886031328089d840a/sympy-1.13.1-py3-none-any.whl.metadata
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch>=1.11.0->sentence-transformers)
#   Obtaining dependency information for mpmath<1.4,>=1.1.0 from https://files.pythonhosted.org/packages/43/e3/7d92a15f894aa0c9c4b49b8ee9ac9850d6e63b03c9c32c0367a13ae62209/mpmath-1.3.0-py3-none-any.whl.metadata
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: numpy>=1.17 in /databricks/python3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.23.5)
# Collecting regex!=2019.12.17 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Obtaining dependency information for regex!=2019.12.17 from https://files.pythonhosted.org/packages/bf/ce/0d0e61429f603bac433910d99ef1a02ce45a8967ffbe3cbee48599e62d88/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/40.5 kB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 5.9 MB/s eta 0:00:00
# Collecting tokenizers<0.22,>=0.21 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Obtaining dependency information for tokenizers<0.22,>=0.21 from https://files.pythonhosted.org/packages/22/06/69d7ce374747edaf1695a4f61b83570d91cc8bbfc51ccfecf76f56ab4aac/tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.4.1 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Obtaining dependency information for safetensors>=0.4.1 from https://files.pythonhosted.org/packages/e6/ee/69e498a892f208bd1da4104d4b9be887f8611bf4942144718b6738482250/safetensors-0.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading safetensors-0.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: joblib>=1.1.1 in /databricks/python3/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /databricks/python3/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.11.0->sentence-transformers)
#   Obtaining dependency information for MarkupSafe>=2.0 from https://files.pythonhosted.org/packages/f1/a4/aefb044a2cd8d7334c8a47d3fb2c9f328ac48cb349468cc31c20b539305f/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /databricks/python3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2023.7.22)
# Downloading sentence_transformers-3.3.1-py3-none-any.whl (268 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/268.8 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 266.2/268.8 kB 8.1 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 7.1 MB/s eta 0:00:00
# Downloading huggingface_hub-0.26.5-py3-none-any.whl (447 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# Collecting faiss-cpu
#   Obtaining dependency information for faiss-cpu from https://files.pythonhosted.org/packages/e4/9c/aed8b7c6c490c777c404131b3f6a68e4924fbc149620dc6d6a3563435371/faiss_cpu-1.9.0.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading faiss_cpu-1.9.0.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Collecting numpy<3.0,>=1.25.0 (from faiss-cpu)
#   Obtaining dependency information for numpy<3.0,>=1.25.0 from https://files.pythonhosted.org/packages/52/33/10825f580f42a353f744abc450dcd2a4b1e6f1931abb0ccbd1d63bd3993c/numpy-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading numpy-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/62.0 kB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /databricks/python3/lib/python3.11/site-packages (from faiss-cpu) (23.2)
# Downloading faiss_cpu-1.9.0.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/27.5 MB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/27.5 MB 7.4 MB/s eta 0:00:04
#    ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.6/27.5 MB 8.4 MB/s eta 0:00:04
#    ━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/27.5 MB 9.5 MB/s eta 0:00:03
#    ━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/27.5 MB 10.4 MB/s eta 0:00:03
#    ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/27.5 MB 11.9 MB/s eta 0:00:03
#    ━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/27.5 MB 13.8 MB/s eta 0:00:02
#    ━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/27.5 MB 15.0 MB/s eta 0:00:02
#    ━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/27.5 MB 15.6 MB/s eta 0:00:02
#    ━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/27.5 MB 17.2 MB/s eta 0:00:02
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/27.5 MB 20.2 MB/s eta 0:00:02
#    ━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/27.5 MB 23.5 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━ 11.4/27.5 MB 34.7 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━ 14.7/27.5 MB 60.7 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━ 18.3/27.5 MB 85.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━ 21.6/27.5 MB 95.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 27.3/27.5 MB 127.1 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 27.5/27.5 MB 123.4 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 27.5/27.5 MB 123.4 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 27.5/27.5 MB 123.4 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 27.5/27.5 MB 123.4 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 43.9 MB/s eta 0:00:00
# Downloading numpy-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/16.4 MB ? eta -:--:--
#    ━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/16.4 MB 160.9 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━ 10.5/16.4 MB 152.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━ 13.6/16.4 MB 143.5 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━ 13.6/16.4 MB 143.5 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━ 13.6/16.4 MB 143.5 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 16.4/16.4 MB 63.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 16.4/16.4 MB 63.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 42.0 MB/s eta 0:00:00
# Installing collected packages: numpy, faiss-cpu
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Not uninstalling numpy at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-bc6dfde1-6aec-4884-b6c4-2cbadc1cdb6d
#     Can't uninstall 'numpy'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scipy 1.11.1 requires numpy<1.28.0,>=1.21.6, but you have numpy 2.2.0 which is incompatible.
# Successfully installed faiss-cpu-1.9.0.post1 numpy-2.2.0
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# Collecting PyMuPDF
#   Obtaining dependency information for PyMuPDF from https://files.pythonhosted.org/packages/6b/ea/08041590cc1a8c66f5fefc3edd0b57f36b9225524586848d27ab470430e7/pymupdf-1.25.0-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata
#   Downloading pymupdf-1.25.0-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: Pillow in /databricks/python3/lib/python3.11/site-packages (9.4.0)
# Requirement already satisfied: numpy in /local_disk0/.ephemeral_nfs/envs/pythonEnv-bc6dfde1-6aec-4884-b6c4-2cbadc1cdb6d/lib/python3.11/site-packages (2.2.0)
# Downloading pymupdf-1.25.0-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (20.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/20.0 MB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.1/20.0 MB 3.8 MB/s eta 0:00:06
#    ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/20.0 MB 5.2 MB/s eta 0:00:04
#    ━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.6/20.0 MB 6.1 MB/s eta 0:00:04
#    ━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.9/20.0 MB 6.8 MB/s eta 0:00:03
#    ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/20.0 MB 7.5 MB/s eta 0:00:03
#    ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/20.0 MB 8.3 MB/s eta 0:00:03
#    ━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/20.0 MB 9.2 MB/s eta 0:00:02
#    ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/20.0 MB 10.2 MB/s eta 0:00:02
#    ━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/20.0 MB 11.4 MB/s eta 0:00:02
#    ━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/20.0 MB 12.6 MB/s eta 0:00:02
#    ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/20.0 MB 13.9 MB/s eta 0:00:02
#    ━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/20.0 MB 14.5 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/20.0 MB 16.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━ 8.8/20.0 MB 18.3 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━ 10.5/20.0 MB 21.8 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━ 12.7/20.0 MB 34.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 15.2/20.0 MB 45.9 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━ 17.3/20.0 MB 55.9 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 20.0/20.0 MB 69.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 20.0/20.0 MB 69.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 20.0/20.0 MB 69.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 39.4 MB/s eta 0:00:00
# Installing collected packages: PyMuPDF
# Successfully installed PyMuPDF-1.25.0
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
pip install langchain
# Out:
# Collecting langchain
#   Obtaining dependency information for langchain from https://files.pythonhosted.org/packages/b3/0c/e123fbfe824b765c4534f954e3418fca7a52adb635cc2f258803ce063bd5/langchain-0.3.10-py3-none-any.whl.metadata
#   Downloading langchain-0.3.10-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in /databricks/python3/lib/python3.11/site-packages (from langchain) (6.0)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Obtaining dependency information for SQLAlchemy<3,>=1.4 from https://files.pythonhosted.org/packages/b4/5f/95e0ed74093ac3c0db6acfa944d4d8ac6284ef5e1136b878a327ea1f975a/SQLAlchemy-2.0.36-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading SQLAlchemy-2.0.36-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain)
#   Obtaining dependency information for aiohttp<4.0.0,>=3.8.3 from https://files.pythonhosted.org/packages/7c/b8/df6d76a149cbd969a58da478baec0be617287c496c842ddf21fe6bce07b3/aiohttp-3.11.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading aiohttp-3.11.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting langchain-core<0.4.0,>=0.3.22 (from langchain)
#   Obtaining dependency information for langchain-core<0.4.0,>=0.3.22 from https://files.pythonhosted.org/packages/d1/36/8d0d84bf9867185c121a25e5296c6706e8f234ca815bf847178ac2f02a1b/langchain_core-0.3.22-py3-none-any.whl.metadata
#   Downloading langchain_core-0.3.22-py3-none-any.whl.metadata (6.3 kB)
# Collecting langchain-text-splitters<0.4.0,>=0.3.0 (from langchain)
#   Obtaining dependency information for langchain-text-splitters<0.4.0,>=0.3.0 from https://files.pythonhosted.org/packages/ee/c6/5ba25c8bad647e92a92b3066177ab10d78efbd16c0b9919948cdcd18b027/langchain_text_splitters-0.3.2-py3-none-any.whl.metadata
#   Downloading langchain_text_splitters-0.3.2-py3-none-any.whl.metadata (2.3 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Obtaining dependency information for langsmith<0.2.0,>=0.1.17 from https://files.pythonhosted.org/packages/de/f0/63b06b99b730b9954f8709f6f7d9b8d076fa0a973e472efe278089bde42b/langsmith-0.1.147-py3-none-any.whl.metadata
#   Downloading langsmith-0.1.147-py3-none-any.whl.metadata (14 kB)
# Collecting numpy<2,>=1.22.4 (from langchain)
#   Obtaining dependency information for numpy<2,>=1.22.4 from https://files.pythonhosted.org/packages/3a/d0/edc009c27b406c4f9cbc79274d6e46d634d139075492ad055e3d68445925/numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/61.0 kB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.4 MB/s eta 0:00:00
# Collecting pydantic<3.0.0,>=2.7.4 (from langch
ests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Obtaining dependency information for annotated-types>=0.6.0 from https://files.pythonhosted.org/packages/78/b6/6307fbef88d9b5ee7421e68d78a9f162e0da4900bc5f5793f6d3d0e34fb8/annotated_types-0.7.0-py3-none-any.whl.metadata
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.1 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Obtaining dependency information for pydantic-core==2.27.1 from https://files.pythonhosted.org/packages/4a/c1/3e38cd777ef832c4fdce11d204592e135ddeedb6c6f525478a53d1c7d3e5/pydantic_core-2.27.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading pydantic_core-2.27.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting typing-extensions>=4.7 (from langchain-core<0.4.0,>=0.3.22->langchain)
#   Obtaining dependency information for typing-extensions>=4.7 from https://files.pythonhosted.org/packages/26/9f/ad63fc0248c5379346306f8668cda6e2e2e9c95e01216d2b8ffd9ff037d0/typing_extensions-4.12.2-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /databricks/python3/lib/python3.11/site-packages (from requests<3,>=2->langchain) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2023.7.22)
# Collecting greenlet!=0.4.17 (from SQLAlchemy<3,>=1.4->langchain)
#   Obtaining dependency information for greenlet!=0.4.17 from https://files.pythonhosted.org/packages/f7/4b/1c9695aa24f808e156c8f4813f685d975ca73c000c2a5056c514c64980f6/greenlet-3.1.1-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata
#   Downloading greenlet-3.1.1-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting anyio (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain)
#   Obtaining dependency information for anyio from https://files.pythonhosted.org/packages/a0/7a/4daaf3b6c08ad7ceffea4634ec206faeff697526421c20f07628c7372156/anyio-4.7.0-py3-none-any.whl.metadata
#   Downloading anyio-4.7.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain)
#   Obtaining dependency information for httpcore==1.* from https://files.pythonhosted.org/packages/87/f5/72347bc88306acb359581ac4d52f23c0ef445b57157adedb9aee0cd689d2/httpcore-1.0.7-py3-none-any.whl.metadata
#   Downloading httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain)
#   Obtaining dependency information for h11<0.15,>=0.13 from https://files.pythonhosted.org/packages/95/04/ff642e65ad6b90db43e668d70ffb6736436c7ce41fcc549f4e9472234127/h11-0.14.0-py3-none-any.whl.metadata
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.22->langchain)
#   Obtaining dependency information for jsonpointer>=1.9 from https://files.pythonhosted.org/packages/71/92/5e77f98553e9e75130c78900d000368476aed74276eb8ae8796f65f00918/jsonpointer-3.0.0-py2.py3-none-any.whl.metadata
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting sniffio>=1.1 (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain)
#   Obtaining dependency information for sniffio>=1.1 from https://files.pythonhosted.org/packages/e9/44/75a9c9421471a6c4805dbf2356f7c181a29c1879239abab1ea2cc8f38b40/sniffio-1.3.1-py3-none-any.whl.metadata
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Downloading langchain-0.3.10-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.0 MB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 45.2 MB/s eta 0:00:00
# Downloading aiohttp-3.11.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.7 MB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 89.7 MB/s eta 0:00:00
# Downloading langchain_core-0.3.22-py3-none-any.whl (409 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/409.7 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.7/409.7 kB 64.5 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.3.2-py3-none-any.whl (25 kB)
# Downloading langsmith-0.1.147-py3-none-any.whl (311 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/311.8 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.8/311.8 kB 40.8 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/18.3 MB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 7.3/18.3 MB 180.7 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━ 14.3/18.3 MB 192.9 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.3 MB 193.4 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.3 MB 193.4 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 18.2/18.3 MB 193.4 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 68.0 MB/s eta 0:00:00
# Downloading pydantic-2.10.3-py3-none-any.whl (456 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/457.0 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.0/457.0 kB 71.5 MB/s eta 0:00:00
# Downloading pydantic_core-2.27.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/2.1 MB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 63.9 MB/s eta 0:00:00
# Downloading SQLAlchemy-2.0.36-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/3.2 MB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 3.2/3.2 MB 123.9 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 76.4 MB/s eta 0:00:00
# Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl (14 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading attrs-24.2.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/63.0 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 16.8 MB/s eta 0:00:00
# Downloading frozenlist-1.5.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (274 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/274.9 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.9/274.9 kB 26.2 MB/s eta 0:00:00
# Downloading greenlet-3.1.1-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (602 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/602.4 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 602.4/602.4 kB 82.5 MB/s eta 0:00:00
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/73.5 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 18.6 MB/s eta 0:00:00
# Downloading httpcore-1.0.7-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/78.6 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 14.5 MB/s eta 0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading multidict-6.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/129.0 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.0/129.0 kB 31.1 MB/s eta 0:00:00
# Downloading orjson-3.10.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/131.3 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.3/131.3 kB 24.4 MB/s eta 0:00:00
# Downloading propcache-0.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/231.1 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.1/231.1 kB 49.0 MB/s eta 0:00:00
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/54.5 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 11.8 MB/s eta 0:00:00
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading yarl-1.18.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (344 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/344.1 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 344.1/344.1 kB 61.2 MB/s eta 0:00:00
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading anyio-4.7.0-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/93.1 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 18.4 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/58.3 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 10.7 MB/s eta 0:00:00
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: typing-extensions, sniffio, propcache, orjson, numpy, multidict, jsonpointer, h11, greenlet, frozenlist, attrs, annotated-types, aiohappyeyeballs, yarl, SQLAlchemy, requests-toolbelt, pydantic-core, jsonpatch, httpcore, anyio, aiosignal, pydantic, httpx, aiohttp, langsmith, langchain-core, langchain-text-splitters, langchain
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.10.0
#     Not uninstalling typing-extensions at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-bc6dfde1-6aec-4884-b6c4-2cbadc1cdb6d
#     Can't uninstall 'typing_extensions'. No files were found to uninstall.
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.0
#     Uninstalling numpy-2.2.0:
#       Successfully uninstalled numpy-2.2.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.6
#     Not uninstalling pydantic at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-bc6dfde1-6aec-4884-b6c4-2cbadc1cdb6d
#     Can't uninstall 'pydantic'. No files were found to uninstall.
# Successfully installed SQLAlchemy-2.0.36 aiohappyeyeballs-2.4.4 aiohttp-3.11.10 aiosignal-1.3.1 annotated-types-0.7.0 anyio-4.7.0 attrs-24.2.0 frozenlist-1.5.0 greenlet-3.1.1 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.10 langchain-core-0.3.22 langchain-text-splitters-0.3.2 langsmith-0.1.147 multidict-6.1.0 numpy-1.26.4 orjson-3.10.12 propcache-0.2.1 pydantic-2.10.3 pydantic-core-2.27.1 requests-toolbelt-1.0.0 sniffio-1.3.1 typing-extensions-4.12.2 yarl-1.18.3
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
pip install --upgrade pydantic
# Out:
# Requirement already satisfied: pydantic in /local_disk0/.ephemeral_nfs/envs/pythonEnv-bc6dfde1-6aec-4884-b6c4-2cbadc1cdb6d/lib/python3.11/site-packages (2.10.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-bc6dfde1-6aec-4884-b6c4-2cbadc1cdb6d/lib/python3.11/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-bc6dfde1-6aec-4884-b6c4-2cbadc1cdb6d/lib/python3.11/site-packages (from pydantic) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-bc6dfde1-6aec-4884-b6c4-2cbadc1cdb6d/lib/python3.11/site-packages (from pydantic) (4.12.2)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

#
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-bc6dfde1-6aec-4884-b6c4-2cbadc1cdb6d/lib/python3.11/site-packages (from langchain<0.4.0,>=0.3.10->langchain_community) (0.3.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-bc6dfde1-6aec-4884-b6c4-2cbadc1cdb6d/lib/python3.11/site-packages (from langchain<0.4.0,>=0.3.10->langchain_community) (2.10.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-bc6dfde1-6aec-4884-b6c4-2cbadc1cdb6d/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.22->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /databricks/python3/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.22->langchain_community) (23.2)
# Requirement already satisfied: typing-extensions>=4.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-bc6dfde1-6aec-4884-b6c4-2cbadc1cdb6d/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.22->langchain_community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-bc6dfde1-6aec-4884-b6c4-2cbadc1cdb6d/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-bc6dfde1-6aec-4884-b6c4-2cbadc1cdb6d/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.125->langchain_community) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-bc6dfde1-6aec-4884-b6c4-2cbadc1cdb6d/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.125->langchain_community) (1.0.0)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain_community)
#   Obtaining dependency information for python-dotenv>=0.21.0 from https://files.pythonhosted.org/packages/6a/3e/b68c118422ec867fa7ab88444e1274aa40681c606d59ac27de5a5588f082/python_dotenv-1.0.1-py3-none-any.whl.metadata
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.11/site-packages (from requests<3,>=2->langchain_community) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.11/site-packages (from requests<3,>=2->langchain_community) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /databricks/python3/lib/python3.11/site-packages (from requests<3,>=2->langchain_community) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.11/site-packages (from requests<3,>=2->langchain_community) (2023.7.22)
# Requirement already satisfied: greenlet!=0.4.17 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-bc6dfde1-6aec-4884-b6c4-2cbadc1cdb6d/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.1.1)
# Requirement already satisfied: anyio in /local_disk0/.ephemeral_nfs/envs/pythonEnv-bc6dfde1-6aec-4884-b6c4-2cbadc1cdb6d/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (4.7.0)
# Requirement already satisfied: httpcore==1.* in /local_disk0/.ephemeral_nfs/envs/pythonEnv-bc6dfde1-6aec-4884-b6c4-2cbadc1cdb6d/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-bc6dfde1-6aec-4884-b6c4-2cbadc1cdb6d/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-bc6dfde1-6aec-4884-b6c4-2cbadc1cdb6d/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.22->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-bc6dfde1-6aec-4884-b6c4-2cbadc1cdb6d/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.10->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-bc6dfde1-6aec-4884-b6c4-2cbadc1cdb6d/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.10->langchain_community) (2.27.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /databricks/python3/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (0.4.3)
# Requirement already satisfied: sniffio>=1.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-bc6dfde1-6aec-4884-b6c4-2cbadc1cdb6d/lib/python3.11/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (1.3.1)
# Downloading langchain_community-0.3.10-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/2.4 MB ? eta -:--:--
#    ━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.7/2.4 MB 22.9 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 37.0 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading pydantic_settings-2.6.1-py3-none-any.whl (28 kB)
# Downloading marshmallow-3.23.1-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/49.5 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 11.5 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Installing collected packages: typing-inspect, python-dotenv, marshmallow, httpx-sse, dataclasses-json, pydantic-settings, langchain_community
# Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.0 langchain_community-0.3.10 marshmallow-3.23.1 pydantic-settings-2.6.1 python-dotenv-1.0.1 typing-inspect-0.9.0
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
pip install -U langchain-openai
# Out:
# Collecting langchain-openai
#   Obtaining dependency information for langchain-openai from https://files.pythonhosted.org/packages/67/15/b5a83ff73f5550d2be854265dd9c507389d69516391a46a30683a3683fcc/langchain_openai-0.2.11-py3-none-any.whl.metadata
#   Downloading langchain_openai-0.2.11-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.21 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-
lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai<2.0.0,>=1.54.0->langchain-openai) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /databricks/python3/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (1.26.16)
# Downloading langchain_openai-0.2.11-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/50.7 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 3.2 MB/s eta 0:00:00
# Downloading openai-1.57.0-py3-none-any.whl (389 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/389.9 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━ 256.0/389.9 kB 7.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.9/389.9 kB 7.0 MB/s eta 0:00:00
# Downloading tiktoken-0.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.2 MB ? eta -:--:--
#    ━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.4/1.2 MB 11.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━ 0.8/1.2 MB 11.4 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 1.2/1.2 MB 12.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 10.9 MB/s eta 0:00:00
# Downloading jiter-0.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (343 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/343.3 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.3/343.3 kB 14.6 MB/s eta 0:00:00
# Installing collected packages: jiter, tiktoken, openai, langchain-openai
# Successfully installed jiter-0.8.0 langchain-openai-0.2.11 openai-1.57.0 tiktoken-0.8.0
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
## Add all imports here
from pyspark.sql import SparkSession

from pyspark.sql.types import IntegerType, StructType, StructField, StringType, TimestampType

from pyspark.sql.functions import lower, col, min, desc, rank, date_trunc, trim, length, split, size, mean, stddev, min, max, countDistinct, datediff, log, month, year, concat_ws

from pyspark.sql.window import Window

# %% [markdown]
# ```
#
# dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/055ae6fc_7e18_4a39_8058_64082ca6d515.txt
# dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/199c586f_af16_4091_9998_ee4cfc02ee7a.txt
# # dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/199c586f_af16_4091_9998_ee4cfc02ee7a_txt_
# dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/353016ea_a0ff_4154_85bb_1cf8b6cedf20.txt
# dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/ae9efba3_ddc4_43f9_a781_f72019388548.txt
# dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/28658715_b770_4576_9a81_fbb2282a98ea.txt
# dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/b9fd2dd8_181b_494b_ab15_e9f286d668d9.txt
# dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/d22592ac_552f_4ecd_a63d_7663d77ce9ba.txt
# dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/f0f3bc8d_ef38_49ce_a2bd_dfdda982b271.txt
# dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/df6b563d_1ff4_4833_9af8_84431e641e9c.txt
# dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/f73d6f41_0091_4485_8b43_9d38eb98fb36.txt
#
# ```

# %%
spark = SparkSession.builder.appName("medical notes").getOrCreate()

print("df_encounter_types")
encounters_type_schema = StructType([
    StructField("CODE", StringType(), True),
    StructField("DESCRIPTION", StringType(), True)
])
df_encounter_types = spark.read.csv("dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/encounters_types_assignment_1.csv",
                    schema=encounters_type_schema, 
                    header=True)
df_encounter_types.show(2)

print("df_immunizations")
immunizations_schema = StructType([
    StructField("CODE", IntegerType(), True),
    StructField("DESCRIPTION", StringType(), True)
])
df_immunizations = spark.read.csv("dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/immunizations_assignment_1.csv",
                    immunizations_schema, 
                    header=True)
df_immunizations.show(2)

print("df_medications")
medications_schema = StructType([
    StructField("CODE", IntegerType(), True),
    StructField("DESCRIPTION", StringType(), True)
])
df_medications = spark.read.csv("dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/medications_assignment_1.csv",
                    schema=medications_schema, 
                    header=True)
df_medications.show(2)


print("df_observation")
observations_schema = StructType([
    StructField("CODE", StringType(), True),
    StructField("DESCRIPTION", StringType(), True)
])
df_observations = spark.read.csv("dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/observations_assignment_1.csv",
                    schema=observations_schema, 
                    header=False)
df_observations.show(2)


print("df_encounters")
encounters_schema = StructType([
    StructField("PATIENT", StringType(), True),
    StructField("START", TimestampType(), True),
    StructField("CODE", StringType(), True)
])
df_encounters = spark.read.csv("dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/encounters_assignment_1.csv",
                    schema=encounters_schema, 
                    header=True)
df_encounters.show(2)
# Out:
# df_encounter_types
# +---------+--------------------+
# |     CODE|         DESCRIPTION|
# +---------+--------------------+
# |  1505002|Hospital admissio...|
# |162673000|General examinati...|
# +---------+--------------------+
# only showing top 2 rows
#
# df_immunizations
# +----+--------------------+
# |CODE|         DESCRIPTION|
# +----+--------------------+
# |  10|                 IPV|
# | 113|Td (adult) preser...|
# +----+--------------------+
# only showing top 2 rows
#
# df_medications
# +-------+--------------------+
# |   CODE|         DESCRIPTION|
# +-------+--------------------+
# |1000126|1 ML medroxyPROGE...|
# |1000126|1 ML medroxyproge...|
# +-------+--------------------+
# only showing top 2 rows
#
# df_observation
# +-------+--------------------+
# |   CODE|         DESCRIPTION|
# +-------+--------------------+
# |10230-1|Left ventricular ...|
# |10480-2|Estrogen+Progeste...|
# +-------+--------------------+
# only showing top 2 rows
#
# df_encounters
# +--------------------+-------------------+---------+
# |             PATIENT|              START|     CODE|
# +--------------------+-------------------+---------+
# |f0f3bc8d-ef38-49c...|2019-02-16 01:02:32|185345009|
# |f0f3bc8d-ef38-49c...|2019-08-02 01:02:32|410620009|
# +--------------------+-------------------+---------+
# only showing top 2 rows

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, TimestampType
import json

spark = SparkSession.builder.appName("medical_notes").getOrCreate()

#convert dataframes into dicts

immunizations_map = {row['DESCRIPTION']: row['CODE'] for row in df_immunizations.collect()}

medications_map = {row['DESCRIPTION'].lower(): row['CODE'] for row in df_medications.collect()}

observations_map = {row['DESCRIPTION'].lower(): row['CODE'] for row in df_observations.collect()}

encounter_types_map = {row['DESCRIPTION'].lower(): row['CODE'] for row in df_encounter_types.collect()}

# %%
# %env OPENAI_API_KEY=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
# Out:
# env: OPENAI_API_KEY=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

# %%
import json
import tempfile
from typing import List, Optional
from pydantic import BaseModel, Field
from langchain_openai import ChatOpenAI
from pyspark.sql import SparkSession
from datetime import date

########################################
# Define the PatientRecord Schema
########################################

class EncounterType(BaseModel):
    code: str
    description: str


class Encounter(BaseModel):
    date: str
    time: str
    provider_id: str
    facility_id: str


class Address(BaseModel):
    city: str
    state: str


class Demographics(BaseModel):
    name: str
    date_of_birth: str
    age: int
    gender: str
    address: Address
    insurance: str


class Condition(BaseModel):
    code: str
    description: str


class Medication(BaseModel):
    code: str
    description: str


class Immunization(BaseModel):
    code: str
    description: str
    date: str


class VitalMeasurement(BaseModel):
    code: str
    value: float
    unit: str


class BloodPressure(BaseModel):
    systolic: Optional[VitalMeasurement]
    diastolic: Optional[VitalMeasurement]


class CurrentVitals(BaseModel):
    temperature: Optional[VitalMeasurement] = None
    heart_rate: Optional[VitalMeasurement] = None
    blood_pressure: Optional[BloodPressure] = None
    respiratory_rate: Optional[VitalMeasurement] = None
    oxygen_saturation: Optional[VitalMeasurement] = None
    weight: Optional[VitalMeasurement] = None


class BaselineVitals(BaseModel):
    date: str
    height: Optional[VitalMeasurement] = None
    weight: Optional[VitalMeasurement] = None
    bmi: Optional[VitalMeasurement] = None
    bmi_percentile: Optional[VitalMeasurement] = None


class Vitals(BaseModel):
    current: Optional[CurrentVitals]
    baseline: Optional[BaselineVitals]


class RespiratoryTest(BaseModel):
    code: str
    result: str


class RespiratoryPanel(BaseModel):
    influenza_a: Optional[RespiratoryTest] = None
    influenza_b: Optional[RespiratoryTest] = None
    rsv: Optional[RespiratoryTest] = None
    parainfluenza_1: Optional[RespiratoryTest] = None
    parainfluenza_2: Optional[RespiratoryTest] = None
    parainfluenza_3: Optional[RespiratoryTest] = None
    rhinovirus: Optional[RespiratoryTest] = None
    metapneumovirus: Optional[RespiratoryTest] = None
    adenovirus: Optional[RespiratoryTest] = None


class Covid19Test(BaseModel):
    code: str
    description: str
    result: str


class Laboratory(BaseModel):
    covid19: Optional[Covid19Test] = None
    respiratory_panel: Optional[RespiratoryPanel] = None


class Procedure(BaseModel):
    code: str
    description: str
    date: str
    reasonCode: str
    reasonDescription: str


class CarePlan(BaseModel):
    code: str
    description: str
    start: str
    stop: str
    reasonCode: str
    reasonDescription: str


class PatientRecord(BaseModel):
    demographics: Demographics
    encounter: Optional[Encounter] = None
    conditions: Optional[List[Condition]] = None
    medications: Optional[List[Medication]] = None
    immunizations: Optional[List[Immunization]] = None
    vitals: Optional[Vitals] = None
    laboratory: Optional[Laboratory] = None
    procedures: Optional[List[Procedure]] = None

########################################
# Paths to Encounter Notes
########################################

note_files = [
    "dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/055ae6fc_7e18_4a39_8058_64082ca6d515.txt",
    "dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/199c586f_af16_4091_9998_ee4cfc02ee7a.txt",
    "dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/353016ea_a0ff_4154_85bb_1cf8b6cedf20.txt",
    "dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/ae9efba3_ddc4_43f9_a781_f72019388548.txt",
    "dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/28658715_b770_4576_9a81_fbb2282a98ea.txt",
    "dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/b9fd2dd8_181b_494b_ab15_e9f286d668d9.txt",
    "dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/d22592ac_552f_4ecd_a63d_7663d77ce9ba.txt",
    "dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/f0f3bc8d_ef38_49ce_a2bd_dfdda982b271.txt",
    "dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/df6b563d_1ff4_4833_9af8_84431e641e9c.txt",
    "dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/f73d6f41_0091_4485_8b43_9d38eb98fb36.txt"
]

########################################
# Use LLM to Extract Structured Data
########################################

spark = SparkSession.builder.appName("patient_record_conversion").getOrCreate()

llm = ChatOpenAI(model="gpt-4o", temperature=0)

all_records = []

for file_path in note_files:

    dbutils.fs.cp(file_path, file_path.replace("dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/", "file:/tmp/"))
    file_location = file_path.replace("dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/", "/tmp/")
    
    local_path = file_location

    with open(local_path, "r") as f:
        note_text = f.read()

    # Prompt the LLM
    prompt = f"""
    You are a helpful medical data assistant. Given the patient note below, extract the relevant data and produce a JSON response that matches this Pydantic schema:

    {json.dumps(PatientRecord.model_json_schema(), indent=2)}

    Fill in as much as possible based on the note. Use 'Not Available' if not found. Please output only valid JSON and nothing else.


    Patient note:
    {note_text}
    """

    response = llm.invoke(prompt)
    
    print(response.content)


    # Validate response
    try:
        json_str = response.content.strip()
        if json_str.startswith("```"):
            json_str = json_str.strip("```").strip()
        data = json.loads(json_str)
        patient_record = PatientRecord(**data)
        all_records.append(patient_record.dict())  # convert to dict for Spark
        
    except Exception as e:
        print(f"Validation error for {file_path}: {e}")
        continue

########################################
# Convert all collected records to a Spark DF and write to Parquet
########################################

# Create DataFrame from the list of dicts
# Each element of all_records is a dictionary matching the PatientRecord schema
if all_records:
    # Convert the list of records to an RDD
    rdd = spark.sparkContext.parallelize([json.dumps(rec) for rec in all_records])
    # Read the RDD into a DataFrame
    df = spark.read.json(rdd)
    
    # Show the contents of the DataFrame for completeness checking
    df.show(truncate=False)
    df.printSchema()

    # Comment out the Parquet writing lines for now
    # output_path = "dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/patient_records.parquet"
    # df.write.mode("overwrite").parquet(output_path)
    # print(f"Parquet file written to {output_path}")
else:
    print("No valid records were produced.")
# Out:
# ```json
# {
#   "demographics": {
#     "name": "Jeffrey Greenfelder",
#     "date_of_birth": "2005-01-16",
#     "age": 15,
#     "gender": "Male",
#     "address": {
#       "city": "Springfield",
#       "state": "Massachusetts"
#     },
#     "insurance": "Guardian"
#   },
#   "encounter": {
#     "date": "2020-03-02",
#     "time": "15:45",
#     "provider_id": "e2c226c2-3e1e-3d0b-b997-ce9544c10528",
#     "facility_id": "5103c940-0c08-392f-95cd-446e0cea042a"
#   },
#   "conditions": [
#     {
#       "code": "E66.9",
#       "description": "Obesity"
#     },
#     {
#       "code": "U07.1",
#       "description": "Suspected COVID-19 with severe symptoms"
#     },
#     {
#       "code": "R09.02",
#       "description": "Severe hypoxemia"
#     },
#     {
#       "code": "R00.0",
#       "description": "Tachycardia"
#     },
#     {
#       "code": "R50.9",
#       "description": "High-grade fever"
#     }
#   ],
#   "medications": null,
#   "immunizations": [
#     {
#       "code": "J07BB02",
#       "description": "Influenza vaccine",
#       "date": "2020-02-23"
#     }
#   ],
#   "vitals": {
#     "current": {
#       "temperature": {
#         "code": "8310-5",
#         "value": 39.3,
#         "unit": "°C"
#       },
#       "heart_rate": {
#         "code": "8867-4",
#         "value": 131.1,
#         "unit": "/min"
#       },
#       "blood_pressure": {
#         "systolic": {
#           "code": "8480-6",
#           "value": 120,
#           "unit": "mmHg"
#         },
#         "diastolic": {
#           "code": "8462-4",
#           "value": 73,
#           "unit": "mmHg"
#         }
#       },
#       "respiratory_rate": {
#         "code": "9279-1",
#         "value": 27.6,
#         "unit": "/min"
#       },
#       "oxygen_saturation": {
#         "code": "59408-5",
#         "value": 75.8,
#         "unit": "%"
#       },
#       "weight": {
#         "code": "29463-7",
#         "value": 81.2,
#         "unit": "kg"
#       }
#     },
#     "baseline": {
#       "date": "2020-02-23",
#       "height": {
#         "code": "8302-2",
#         "value": 155.0,
#         "unit": "cm"
#       },
#       "weight": {
#         "code": "29463-7",
#         "value": 81.2,
#         "unit": "kg"
#       },
#       "bmi": {
#         "code": "39156-5",
#         "value": 33.8,
#         "unit": "kg/m²"
#       },
#       "bmi_percentile": {
#         "code": "59574-4",
#         "value": 99.1,
#         "unit": "percentile"
#       }
#     }
#   },
#   "laboratory": {
#     "covid19": {
#       "code": "94500-6",
#       "description": "SARS-CoV-2 RNA",
#       "result": "Not detected"
#     },
#     "respiratory_panel": {
#       "influenza_a": {
#         "code": "LP6464-4",
#         "result": "Negative"
#       },
#       "influenza_b": {
#         "code": "LP6466-9",
#         "result": "Negative"
#       },
#       "rsv": {
#         "code": "LP6467-7",
#         "result": "Negative"
#       },
#       "parainfluenza_1": {
#         "code": "LP6468-5",
#         "result": "Negative"
#       },
#       "parainfluenza_2": {
#         "code": "LP6469-3",
#         "result": "Negative"
#       },
#       "parainfluenza_3": {
#         "code": "LP6470-1",
#         "result": "Negative"
#       },
#       "rhinovirus": {
#         "code": "LP6471-9",
#         "result": "Negative"
#       },
#       "metapneumovirus": {
#         "code": "LP6472-7",
#         "result": "Negative"
#       },
#       "adenovirus": {
#         "code": "LP6473-5",
#         "result": "Negative"
#       }
#     }
#   },
#   "procedures": null
# }
# ```
# Validation error for dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/055ae6fc_7e18_4a39_8058_64082ca6d515.txt: Expecting value: line 1 column 1 (char 0)
# ```json
# {
#   "demographics": {
#     "name": "Jimmie Harris",
#     "date_of_birth": "2004-01-09",
#     "age": 16,
#     "gender": "Female",
#     "address": {
#       "city": "Pembroke",
#       "state": "MA"
#     },
#     "insurance": "Medicare/Medicaid"
#   },
#   "encounter": {
#     "date": "2020-03-02",
#     "time": "04:15",
#     "provider_id": "8be741d6-44d0-3412-88dd-4987e1559f0b",
#     "facility_id": "b1ddf812-1fdd-3adf-b1d5-32cc8bd07ebb"
#   },
#   "conditions": [
#     {
#       "code": "U07.1",
#       "description": "Confirmed COVID-19 infection with severe symptoms"
#     },
#     {
#       "code": "R09.02",
#       "description": "Acute hypoxemia requiring intervention"
#     },
#     {
#       "code": "R50.9",
#       "description": "High-grade fever"
#     },
#     {
#       "code": "R11.2",
#       "description": "GI symptoms with risk of dehydration"
#     }
#   ],
#   "medications": [
#     {
#       "code": "Jolivette",
#       "description": "Jolivette (oral contraceptive)"
#     }
#   ],
#   "immunizations": [
#     {
#       "code": "FLU",
#       "description": "Influenza vaccine",
#       "date": "2020-02-21"
#     },
#     {
#       "code": "MCV4",
#       "description": "Meningococcal vaccine",
#       "date": "2020-02-21"
#     }
#   ],
#   "vitals": {
#     "current": {
#       "temperature": {
#         "code": "8310-5",
#         "value": 40.7,
#         "unit": "°C"
#       },
#       "heart_rate": {
#         "code": "8867-4",
#         "value": 98,
#         "unit": "/min"
#       },
#       "blood_pressure": {
#         "systolic": {
#           "code": "8480-6",
#           "value": 120,
#           "unit": "mmHg"
#         },
#         "diastolic": {
#           "code": "8462-4",
#           "value": 89,
#           "unit": "mmHg"
#         }
#       },
#       "respiratory_rate": {
#         "code": "9279-1",
#         "value": 22,
#         "unit": "/min"
#       },
#       "oxygen_saturation": {
#         "code": "59408-5",
#         "value": 78.2,
#         "unit": "%"
#       },
#       "weight": {
#         "code": "29463-7",
#         "value": 45.3,
#         "unit": "kg"
#       }
#     },
#     "baseline": {
#       "date": "2020-02-21",
#       "height": {
#         "code": "8302-2",
#         "value": 149.3,
#         "unit": "cm"
#       },
#       "weight": {
#         "code": "29463-7",
#         "value": 45.3,
#         "unit": "kg"
#       },
#       "bmi": {
#         "code": "39156-5",
#         "value": 20.3,
#         "unit": "kg/m2"
#       },
#       "bmi_percentile": {
#         "code": "59574-4",
#         "value": 47.6,
#         "unit": "%"
#       }
#     }
#   },
#   "laboratory": {
#     "covid19": {
#       "code": "94500-6",
#       "description": "COVID-19 PCR",
#       "result": "POSITIVE"
#     },
#     "respiratory_panel": {
#       "influenza_a": {
#         "code": "FLUA",
#         "result": "Negative"
#       },
#       "influenza_b": {
#         "code": "FLUB",
#         "result": "Negative"
#       },
#       "rsv": {
#         "code": "RSV",
#         "result": "Negative"
#       },
#       "parainfluenza_1": {
#         "code": "PARA1",
#         "result": "Negative"
#       },
#       "parainfluenza_2": {
#         "code": "PARA2",
#         "result": "Negative"
#       },
#       "parainfluenza_3": {
#         "code": "PARA3",
#         "result": "Negative"
#       },
#       "rhinovirus": {
#         "code": "RHINO",
#         "result": "Negative"
#       },
#       "metapneumovirus": {
#         "code": "HMPV",
#         "result": "Negative"
#       },
#       "adenovirus": {
#         "code": "ADENO",
#         "result": "Negative"
#       }
#     }
#   },
#   "procedures": null
# }
# ```
# Validation error for dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/199c586f_af16_4091_9998_ee4cfc02ee7a.txt: Expecting value: line 1 column 1 (char 0)
# ```json
# {
#   "demographics": {
#     "name": "Gregorio Auer",
#     "date_of_birth": "11/15/1996",
#     "age": 23,
#     "gender": "Male",
#     "address": {
#       "city": "Boston",
#       "state": "MA"
#     },
#     "insurance": "Medicare/Medicaid"
#   },
#   "encounter": {
#     "date": "March 3, 2020",
#     "time": "00:58-02:19",
#     "provider_id": "6ba172e8-ae6d-3c6c-9f49-38096f9d1e1e",
#     "facility_id": "d78e84ec-30aa-3bba-a33a-f29a3a454662"
#   },
#   "conditions": [
#     {
#       "code": "U07.1",
#       "description": "COVID-19, virus identified"
#     },
#     {
#       "code": "R09.02",
#       "description": "Hypoxemia"
#     },
#     {
#       "code": "R00.1",
#       "description": "Bradycardia, unspecified"
#     },
#     {
#       "code": "J00",
#       "description": "Acute nasopharyngitis [common cold]"
#     }
#   ],
#   "medications": null,
#   "immunizations": null,
#   "vitals": {
#     "current": {
#       "temperature": {
#         "code": "8310-5",
#         "value": 38.8,
#         "unit": "°C"
#       },
#       "heart_rate": {
#         "code": "8867-4",
#         "value": 51,
#         "unit": "/min"
#       },
#       "blood_pressure": {
#         "systolic": {
#           "code": "8480-6",
#           "value": 116,
#           "unit": "mmHg"
#         },
#         "diastolic": {
#           "code": "8462-4",
#           "value": 80,
#           "unit": "mmHg"
#         }
#       },
#       "respiratory_rate": {
#         "code": "9279-1",
#         "value": 19,
#         "unit": "/min"
#       },
#       "oxygen_saturation": {
#         "code": "59408-5",
#         "value": 77.6,
#         "unit": "%"
#       },
#       "weight": {
#         "code": "29463-7",
#         "value": 91.2,
#         "unit": "kg"
#       }
#     },
#     "baseline": null
#   },
#   "laboratory": {
#     "covid19": {
#       "code": "94500-6",
#       "description": "SARS-CoV-2 RNA [Presence] in Respiratory specimen by NAA with probe detection",
#       "result": "Positive"
#     },
#     "respiratory_panel": {
#       "influenza_a": {
#         "code": "34487-9",
#         "result": "Negative"
#       },
#       "influenza_b": {
#         "code": "34488-7",
#         "result": "Negative"
#       },
#       "rsv": null,
#       "parainfluenza_1": null,
#       "parainfluenza_2": null,
#       "parainfluenza_3": null,
#       "rhinovirus": null,
#       "metapneumovirus": null,
#       "adenovirus": null
#     }
#   },
#   "procedures": null
# }
# ```
# Validation error for dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/353016ea_a0ff_4154_85bb_1cf8b6cedf20.txt: Expecting value: line 1 column 1 (char 0)
# ```json
# {
#   "demographics": {
#     "name": "Jayson Fadel",
#     "date_of_birth": "6/30/1992",
#     "age": 27,
#     "gender": "Male",
#     "address": {
#       "city": "Chicopee",
#       "state": "MA"
#     },
#     "insurance": "Guardian"
#   },
#   "encounter": {
#     "date": "March 11, 2020",
#     "time": "10:51",
#     "provider_id": "f59948a6-b07a-3248-9661-60f5924b644b",
#     "facility_id": "5d4b9df1-93ae-3bc9-b680-03249990e558"
#   },
#   "conditions": [
#     {
#       "code": "Not Available",
#       "description": "Confirmed COVID-19 infection with severe symptoms"
#     },
#     {
#       "code": "Not Available",
#       "description": "Hypertensive urgency (BP 187/96)"
#     },
#     {
#       "code": "Not Available",
#       "description": "Acute hypoxemia"
#     },
#     {
#       "code": "Not Available",
#       "description": "Severe fever"
#     },
#     {
#       "code": "Not Available",
#       "description": "Significant tachycardia"
#     },
#     {
#       "code": "Not Available",
#       "description": "Gastrointestinal symptoms with risk of dehydration"
#     }
#   ],
#   "medications": [
#     {
#       "code": "Not Available",
#       "description": "amLODIPine/Hydrochlorothiazide/Olmesartan (5/12.5/20 mg) daily"
#     }
#   ],
#   "immunizations": [
#     {
#       "code": "Not Available",
#       "description": "Influenza vaccine",
#       "date": "10/15/2019"
#     }
#   ],
#   "vitals": {
#     "current": {
#       "temperature": {
#         "code": "Not Available",
#         "value": 41.1,
#         "unit": "°C"
#       },
#       "heart_rate": {
#         "code": "Not Available",
#         "value": 187,
#         "unit": "/min"
#       },
#       "blood_pressure": {
#         "systolic": {
#           "code": "Not Available",
#           "value": 187,
#           "unit": "mmHg"
#         },
#         "diastolic": {
#           "code": "Not Available",
#           "value": 96,
#           "unit": "mmHg"
#         }
#       },
#       "respiratory_rate": {
#         "code": "Not Available",
#         "value": 33,
#         "unit": "/min"
#       },
#       "oxygen_saturation": {
#         "code": "Not Available",
#         "value": 88.7,
#         "unit": "%"
#       },
#       "weight": {
#         "code": "Not Available",
#         "value": 68.2,
#         "unit": "kg"
#       }
#     },
#     "baseline": {
#       "date": "10/15/2019",
#       "height": {
#         "code": "Not Available",
#         "value": 165.7,
#         "unit": "cm"
#       },
#       "weight": {
#         "code": "Not Available",
#         "value": 68.2,
#         "unit": "kg"
#       },
#       "bmi": {
#         "code": "Not Available",
#         "value": 24.8,
#         "unit": "kg/m2"
#       },
#       "bmi_percentile": null
#     }
#   },
#   "laboratory": {
#     "covid19": {
#       "code": "Not Available",
#       "description": "COVID-19 PCR",
#       "result": "POSITIVE"
#     },
#     "respiratory_panel": {
#       "influenza_a": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "influenza_b": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "rsv": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "parainfluenza_1": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "parainfluenza_2": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "parainfluenza_3": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "rhinovirus": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "metapneumovirus": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "adenovirus": {
#         "code": "Not Available",
#         "result": "Negative"
#       }
#     }
#   },
#   "procedures": null
# }
# ```
# Validation error for dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/ae9efba3_ddc4_43f9_a781_f72019388548.txt: Expecting value: line 1 column 1 (char 0)
# ```json
# {
#   "demographics": {
#     "name": "Mrs. Karyn217 Metz686",
#     "date_of_birth": "1991-07-31",
#     "age": 28,
#     "gender": "Female",
#     "address": {
#       "city": "Medfield",
#       "state": "Massachusetts"
#     },
#     "insurance": "Guardian"
#   },
#   "encounter": {
#     "date": "2020-02-29",
#     "time": "04:48",
#     "provider_id": "bc4a66b7-a2ba-3ad3-af08-2975489d8495",
#     "facility_id": "3bd5eda0-16da-3ba5-8500-4dfd6ae118b8"
#   },
#   "conditions": [
#     {
#       "code": "Not Available",
#       "description": "Brain damage - traumatic"
#     },
#     {
#       "code": "Not Available",
#       "description": "History of miscarriage in first trimester"
#     },
#     {
#       "code": "Not Available",
#       "description": "Currently pregnant"
#     },
#     {
#       "code": "Not Available",
#       "description": "Confirmed COVID-19 infection with severe symptoms"
#     },
#     {
#       "code": "Not Available",
#       "description": "Acute hypoxemia"
#     },
#     {
#       "code": "Not Available",
#       "description": "High-grade fever"
#     },
#     {
#       "code": "Not Available",
#       "description": "First trimester pregnancy (high-risk condition with COVID-19)"
#     },
#     {
#       "code": "Not Available",
#       "description": "Myalgia"
#     },
#     {
#       "code": "Not Available",
#       "description": "Arthralgia"
#     },
#     {
#       "code": "Not Available",
#       "description": "Ageusia (loss of taste)"
#     }
#   ],
#   "medications": null,
#   "immunizations": [
#     {
#       "code": "Not Available",
#       "description": "Influenza vaccine",
#       "date": "2019-10-09"
#     }
#   ],
#   "vitals": {
#     "current": {
#       "temperature": {
#         "code": "Not Available",
#         "value": 41.5,
#         "unit": "°C"
#       },
#       "heart_rate": {
#         "code": "Not Available",
#         "value": 84.4,
#         "unit": "/min"
#       },
#       "blood_pressure": {
#         "systolic": {
#           "code": "Not Available",
#           "value": 108,
#           "unit": "mmHg"
#         },
#         "diastolic": {
#           "code": "Not Available",
#           "value": 84,
#           "unit": "mmHg"
#         }
#       },
#       "respiratory_rate": {
#         "code": "Not Available",
#         "value": 27.3,
#         "unit": "/min"
#       },
#       "oxygen_saturation": {
#         "code": "Not Available",
#         "value": 86.7,
#         "unit": "%"
#       },
#       "weight": {
#         "code": "Not Available",
#         "value": 74.0,
#         "unit": "kg"
#       }
#     },
#     "baseline": {
#       "date": "2019-10-09",
#       "height": {
#         "code": "Not Available",
#         "value": 167.3,
#         "unit": "cm"
#       },
#       "weight": {
#         "code": "Not Available",
#         "value": 74.0,
#         "unit": "kg"
#       },
#       "bmi": {
#         "code": "Not Available",
#         "value": 26.4,
#         "unit": "kg/m²"
#       },
#       "bmi_percentile": null
#     }
#   },
#   "laboratory": {
#     "covid19": {
#       "code": "Not Available",
#       "description": "COVID-19 PCR",
#       "result": "POSITIVE"
#     },
#     "respiratory_panel": {
#       "influenza_a": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "influenza_b": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "rsv": null,
#       "parainfluenza_1": null,
#       "parainfluenza_2": null,
#       "parainfluenza_3": null,
#       "rhinovirus": null,
#       "metapneumovirus": null,
#       "adenovirus": null
#     }
#   },
#   "procedures": [
#     {
#       "code": "Not Available",
#       "description": "Complete prenatal panel",
#       "date": "2019-12-03",
#       "reasonCode": "Not Available",
#       "reasonDescription": "Regular prenatal care"
#     },
#     {
#       "code": "Not Available",
#       "description": "Fetal anatomy study",
#       "date": "2020-01-28",
#       "reasonCode": "Not Available",
#       "reasonDescription": "Regular prenatal care"
#     },
#     {
#       "code": "Not Available",
#       "description": "Alpha-fetoprotein test",
#       "date": "2020-01-28",
#       "reasonCode": "Not Available",
#       "reasonDescription": "Regular prenatal care"
#     }
#   ]
# }
# ```
# Validation error for dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/28658715_b770_4576_9a81_fbb2282a98ea.txt: Expecting value: line 1 column 1 (char 0)
# com.databricks.backend.common.rpc.CommandCancelledException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$5(SequenceExecutionState.scala:136)
# 	at scala.Option.getOrElse(Option.scala:189)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:136)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:133)
# 	at scala.collection.immutable.Range.foreach(Range.scala:158)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:133)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:728)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:446)
# 	at scala.Option.getOrElse(Option.scala:189)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:446)
# 	at com.databricks.spark.chauffeur.ExecutionContextManagerV1.cancelExecution(ExecutionContextManagerV1.scala:464)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:571)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:527)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:631)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:651)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:48)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:276)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:272)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:46)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:43)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionContext(ChauffeurState.scala:51)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:95)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:76)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionTags(ChauffeurState.scala:51)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:626)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:536)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperationWithResultTags(ChauffeurState.scala:51)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:528)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:496)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperation(ChauffeurState.scala:51)
# 	at com.databricks.spark.chauffeur.ChauffeurState.process(ChauffeurState.scala:553)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.handleDriverRequest$1(Chauffeur.scala:830)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.handleDriverRequestWithUsageLogging$1(Chauffeur.scala:846)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:910)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:703)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive0$2(ServerBackend.scala:174)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:200)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:200)
# 	at com.databricks.rpc.ServerBackend.internalReceive0(ServerBackend.scala:171)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive$1(ServerBackend.scala:147)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:527)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:631)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:651)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:48)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:276)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:272)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:46)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:43)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:22)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:95)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:76)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:22)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:626)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:536)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:22)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:528)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:496)
# 	at com.databricks.rpc.ServerBackend.recordOperation(ServerBackend.scala:22)
# 	at com.databricks.rpc.ServerBackend.internalReceive(ServerBackend.scala:146)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRPC(JettyServer.scala:1021)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRequestAndRespond(JettyServer.scala:942)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$6(JettyServer.scala:546)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$6$adapted(JettyServer.scala:515)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$6(ActivityContextFactory.scala:545)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:48)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:276)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:272)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:46)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:43)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:48)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$3(ActivityContextFactory.scala:545)
# 	at com.databricks.context.integrity.IntegrityCheckContext$ThreadLocalStorage$.withValue(IntegrityCheckContext.scala:73)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:523)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withServiceRequestActivity(ActivityContextFactory.scala:175)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleHttp(JettyServer.scala:515)
# 	at com.databricks.rpc.JettyServer$RequestManager.doPost(JettyServer.scala:405)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:665)
# 	at com.databricks.rpc.HttpServletWithPatch.service(HttpServletWithPatch.scala:33)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:750)
# 	at org.eclipse.jetty.servlet.ServletHolder.handle(ServletHolder.java:799)
# 	at org.eclipse.jetty.servlet.ServletHandler.doHandle(ServletHandler.java:554)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.nextScope(ScopedHandler.java:190)
# 	at org.eclipse.jetty.servlet.ServletHandler.doScope(ServletHandler.java:505)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.handle(ScopedHandler.java:141)
# 	at org.eclipse.jetty.server.handler.HandlerWrapper.handle(HandlerWrapper.java:127)
# 	at org.eclipse.jetty.server.Server.handle(Server.java:516)
# 	at org.eclipse.jetty.server.HttpChannel.lambda$handle$1(HttpChannel.java:487)
# 	at org.eclipse.jetty.server.HttpChannel.dispatch(HttpChannel.java:732)
# 	at org.eclipse.jetty.server.HttpChannel.handle(HttpChannel.java:479)
# 	at org.eclipse.jetty.server.HttpConnection.onFillable(HttpConnection.java:277)
# 	at org.eclipse.jetty.io.AbstractConnection$ReadCallback.succeeded(AbstractConnection.java:311)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ssl.SslConnection$DecryptedEndPoint.onFillable(SslConnection.java:555)
# 	at org.eclipse.jetty.io.ssl.SslConnection.onFillable(SslConnection.java:410)
# 	at org.eclipse.jetty.io.ssl.SslConnection$2.succeeded(SslConnection.java:164)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ChannelEndPoint$1.run(ChannelEndPoint.java:104)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.runTask(EatWhatYouKill.java:338)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.doProduce(EatWhatYouKill.java:315)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.tryProduce(EatWhatYouKill.java:173)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.run(EatWhatYouKill.java:131)
# 	at org.eclipse.jetty.util.thread.ReservedThreadExecutor$ReservedThread.run(ReservedThreadExecutor.java:409)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$2(InstrumentedQueuedThreadPool.scala:105)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:48)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:276)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:272)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:46)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:43)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.withAttributionContext(InstrumentedQueuedThreadPool.scala:45)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$1(InstrumentedQueuedThreadPool.scala:105)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads(QueuedThreadPoolInstrumenter.scala:110)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads$(QueuedThreadPoolInstrumenter.scala:107)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.trackActiveThreads(InstrumentedQueuedThreadPool.scala:45)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.run(InstrumentedQueuedThreadPool.scala:87)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool.runJob(QueuedThreadPool.java:883)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool$Runner.run(QueuedThreadPool.java:
bfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/medications_assignment_1.csv</td><td>medications_assignment_1.csv</td><td>8537</td><td>1733432396000</td></tr><tr><td>dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/observations_assignment_1.csv</td><td>observations_assignment_1.csv</td><td>9995</td><td>1733432397000</td></tr><tr><td>dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/openfoodfacts_products_first2000.jsonl</td><td>openfoodfacts_products_first2000.jsonl</td><td>45168439</td><td>1729055557000</td></tr><tr><td>dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/pdf_URLs.txt</td><td>pdf_URLs.txt</td><td>1213</td><td>1732649003000</td></tr><tr><td>dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/test_sentence.txt</td><td>test_sentence.txt</td><td>2363</td><td>1732648998000</td></tr><tr><td>dbf ...

# %%
import json
import tempfile
from typing import List, Optional
from pydantic import BaseModel, Field
from langchain_openai import ChatOpenAI
from pyspark.sql import SparkSession
from datetime import date

########################################
# Define the PatientRecord Schema
########################################

class EncounterType(BaseModel):
    code: str
    description: str

class Encounter(BaseModel):
    date: str
    time: str
    provider_id: str
    facility_id: str

class Address(BaseModel):
    city: str
    state: str

class Demographics(BaseModel):
    name: str
    date_of_birth: str
    age: int
    gender: str
    address: Address
    insurance: str

class Condition(BaseModel):
    code: str
    description: str

class Medication(BaseModel):
    code: str
    description: str

class Immunization(BaseModel):
    code: str
    description: str
    date: str

class VitalMeasurement(BaseModel):
    code: str
    value: float
    unit: str

class BloodPressure(BaseModel):
    systolic: Optional[VitalMeasurement]
    diastolic: Optional[VitalMeasurement]

class CurrentVitals(BaseModel):
    temperature: Optional[VitalMeasurement] = None
    heart_rate: Optional[VitalMeasurement] = None
    blood_pressure: Optional[BloodPressure] = None
    respiratory_rate: Optional[VitalMeasurement] = None
    oxygen_saturation: Optional[VitalMeasurement] = None
    weight: Optional[VitalMeasurement] = None

class BaselineVitals(BaseModel):
    date: str
    height: Optional[VitalMeasurement] = None
    weight: Optional[VitalMeasurement] = None
    bmi: Optional[VitalMeasurement] = None
    bmi_percentile: Optional[VitalMeasurement] = None

class Vitals(BaseModel):
    current: Optional[CurrentVitals]
    baseline: Optional[BaselineVitals]

class RespiratoryTest(BaseModel):
    code: str
    result: str

class RespiratoryPanel(BaseModel):
    influenza_a: Optional[RespiratoryTest] = None
    influenza_b: Optional[RespiratoryTest] = None
    rsv: Optional[RespiratoryTest] = None
    parainfluenza_1: Optional[RespiratoryTest] = None
    parainfluenza_2: Optional[RespiratoryTest] = None
    parainfluenza_3: Optional[RespiratoryTest] = None
    rhinovirus: Optional[RespiratoryTest] = None
    metapneumovirus: Optional[RespiratoryTest] = None
    adenovirus: Optional[RespiratoryTest] = None

class Covid19Test(BaseModel):
    code: str
    description: str
    result: str

class Laboratory(BaseModel):
    covid19: Optional[Covid19Test] = None
    respiratory_panel: Optional[RespiratoryPanel] = None

class Procedure(BaseModel):
    code: str
    description: str
    date: str
    reasonCode: str
    reasonDescription: str

class CarePlan(BaseModel):
    code: str
    description: str
    start: str
    stop: str
    reasonCode: str
    reasonDescription: str

class PatientRecord(BaseModel):
    demographics: Demographics
    encounter: Optional[Encounter] = None
    conditions: Optional[List[Condition]] = None
    medications: Optional[List[Medication]] = None
    immunizations: Optional[List[Immunization]] = None
    vitals: Optional[Vitals] = None
    laboratory: Optional[Laboratory] = None
    procedures: Optional[List[Procedure]] = None

########################################
# Paths to Encounter Notes
########################################

note_files = [
    "dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/055ae6fc_7e18_4a39_8058_64082ca6d515.txt",
    "dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/199c586f_af16_4091_9998_ee4cfc02ee7a.txt",
    "dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/353016ea_a0ff_4154_85bb_1cf8b6cedf20.txt",
    "dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/ae9efba3_ddc4_43f9_a781_f72019388548.txt",
    "dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/28658715_b770_4576_9a81_fbb2282a98ea.txt",
    "dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/b9fd2dd8_181b_494b_ab15_e9f286d668d9.txt",
    "dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/d22592ac_552f_4ecd_a63d_7663d77ce9ba.txt",
    "dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/f0f3bc8d_ef38_49ce_a2bd_dfdda982b271.txt",
    "dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/df6b563d_1ff4_4833_9af8_84431e641e9c.txt",
    "dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/f73d6f41_0091_4485_8b43_9d38eb98fb36.txt"
]

########################################
# Use LLM to Extract Structured Data
########################################

spark = SparkSession.builder.appName("patient_record_conversion").getOrCreate()

llm = ChatOpenAI(model="gpt-4o", temperature=0)

all_records = []

print("Starting processing of patient records...")

for i, file_path in enumerate(note_files, start=1):
    print(f"Processing file {i}/{len(note_files)}: {file_path}")

    # Copy file from DBFS to local tmp
    print("Copying file from DBFS to local /tmp/ directory...")
    dbutils.fs.cp(file_path, file_path.replace("dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/", "file:/tmp/"))
    file_location = file_path.replace("dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/", "/tmp/")
    local_path = file_location

    print("Reading the encounter note file...")
    with open(local_path, "r") as f:
        note_text = f.read()

    print("Preparing the prompt for the LLM...")
    prompt = f"""
    You are a helpful medical data assistant. Given the patient note below, extract the relevant data and produce a JSON response that matches this Pydantic schema:

    {json.dumps(PatientRecord.model_json_schema(), indent=2)}

    Fill in as much as possible based on the note. Use 'Not Available' if not found. Please output only valid JSON and nothing else. Do not include any triple backticks or code fences. Return only raw JSON starting and ending with '{' and '}'.


    Patient note:
    {note_text}
    """

    print("Invoking LLM for extraction...")
    response = llm.invoke(prompt)

    print("LLM response received. Printing response content for debugging:")
    print(response.content)

    # Validate response
    print("Validating JSON response against schema...")
    try:
        json_str = response.content.strip()
        # Remove code fences if any remain
        if json_str.startswith("```"):
            json_str = json_str.strip("```").strip()

        data = json.loads(json_str)
        patient_record = PatientRecord(**data)

        # Apply code mapping
        # Map immunizations
        if patient_record.immunizations:
            for imm in patient_record.immunizations:
                imm_desc = imm.description.strip().lower()
                if imm_desc in immunizations_map:
                    imm.code = immunizations_map[imm_desc]

        # Map medications
        if patient_record.medications:
            for med in patient_record.medications:
                med_desc = med.description.strip().lower()
                if med_desc in medications_map:
                    med.code = medications_map[med_desc]

        # Map observations (for vitals, etc.) - as an example, if a temperature code is "Not Available",
        # we can attempt to find a standard code by known keywords:
        if patient_record.vitals and patient_record.vitals.current:
            curr = patient_record.vitals.current
            if curr.temperature and curr.temperature.code == "Not Available":
                # Example: If we know that temperature -> "Body temperature"
                obs_key = "body temperature"
                if obs_key in observations_map:
                    curr.temperature.code = observations_map[obs_key]

        all_records.append(patient_record.model_dump())
        print("Validation successful. Record appended.")
    except Exception as e:
        print(f"Validation error for {file_path}: {e}")
        continue

print("All files processed. Preparing to create DataFrame...")

if all_records:
    rdd = spark.sparkContext.parallelize([json.dumps(rec) for rec in all_records])
    df = spark.read.json(rdd)

    print("Showing DataFrame preview:")
    df.show(truncate=False)
    df.printSchema()

    # Uncomment if you want to write the DataFrame to Parquet
    # output_path = "dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/patient_records.parquet"
    # print("Writing to Parquet...")
    # df.write.mode("overwrite").parquet(output_path)
    # print(f"Parquet file written to {output_path}")
else:
    print("No valid records were produced.")

print("Processing complete.")
# Out:
# Starting processing of patient records...
# Processing file 1/10: dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/055ae6fc_7e18_4a39_8058_64082ca6d515.txt
# Copying file from DBFS to local /tmp/ directory...
# Reading the encounter note file...
# Preparing the prompt for the LLM...
# Invoking LLM for extraction...
# LLM response received. Printing response content for debugging:
# {
#   "demographics": {
#     "name": "Jeffrey Greenfelder",
#     "date_of_birth": "1/16/2005",
#     "age": 15,
#     "gender": "Male",
#     "address": {
#       "city": "Springfield",
#       "state": "Massachusetts"
#     },
#     "insurance": "Guardian"
#   },
#   "encounter": {
#     "date": "March 2, 2020",
#     "time": "15:45",
#     "provider_id": "e2c226c2-3e1e-3d0b-b997-ce9544c10528",
#     "facility_id": "5103c940-0c08-392f-95cd-446e0cea042a"
#   },
#   "conditions": [
#     {
#       "code": "Not Available",
#       "description": "Suspected COVID-19 with severe symptoms"
#     },
#     {
#       "code": "Not Available",
#       "description": "Severe hypoxemia requiring immediate intervention"
#     },
#     {
#       "code": "Not Available",
#       "description": "Tachycardia (HR 131)"
#     },
#     {
#       "code": "Not Available",
#       "description": "High-grade fever"
#     },
#     {
#       "code": "Not Available",
#       "description": "Obesity (BMI 33.8)"
#     }
#   ],
#   "medications": null,
#   "immunizations": [
#     {
#       "code": "Not Available",
#       "description": "Influenza vaccine",
#       "date": "2/23/2020"
#     }
#   ],
#   "vitals": {
#     "current": {
#       "temperature": {
#         "code": "Not Available",
#         "value": 39.3,
#         "unit": "°C"
#       },
#       "heart_rate": {
#         "code": "Not Available",
#         "value": 131.1,
#         "unit": "/min"
#       },
#       "blood_pressure": {
#         "systolic": {
#           "code": "Not Available",
#           "value": 120,
#           "unit": "mmHg"
#         },
#         "diastolic": {
#           "code": "Not Available",
#           "value": 73,
#           "unit": "mmHg"
#         }
#       },
#       "respiratory_rate": {
#         "code": "Not Available",
#         "value": 27.6,
#         "unit": "/min"
#       },
#       "oxygen_saturation": {
#         "code": "Not Available",
#         "value": 75.8,
#         "unit": "%"
#       },
#       "weight": {
#         "code": "Not Available",
#         "value": 81.2,
#         "unit": "kg"
#       }
#     },
#     "baseline": {
#       "date": "2/23/2020",
#       "height": {
#         "code": "Not Available",
#         "value": 155.0,
#         "unit": "cm"
#       },
#       "weight": {
#         "code": "Not Available",
#         "value": 81.2,
#         "unit": "kg"
#       },
#       "bmi": {
#         "code": "Not Available",
#         "value": 33.8,
#         "unit": "kg/m²"
#       },
#       "bmi_percentile": {
#         "code": "Not Available",
#         "value": 99.1,
#         "unit": "percentile"
#       }
#     }
#   },
#   "laboratory": {
#     "covid19": {
#       "code": "Not Available",
#       "description": "SARS-CoV-2 RNA",
#       "result": "Not detected"
#     },
#     "respiratory_panel": {
#       "influenza_a": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "influenza_b": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "rsv": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "parainfluenza_1": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "parainfluenza_2": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "parainfluenza_3": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "rhinovirus": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "metapneumovirus": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "adenovirus": {
#         "code": "Not Available",
#         "result": "Negative"
#       }
#     }
#   },
#   "procedures": null
# }
# Validating JSON response against schema...
# Validation successful. Record appended.
# Processing file 2/10: dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/199c586f_af16_4091_9998_ee4cfc02ee7a.txt
# Copying file from DBFS to local /tmp/ directory...
# Reading the encounter note file...
# Preparing the prompt for the LLM...
# Invoking LLM for extraction...
# LLM response received. Printing response content for debugging:
# {
#   "demographics": {
#     "name": "Jimmie Harris",
#     "date_of_birth": "2004-01-09",
#     "age": 16,
#     "gender": "Female",
#     "address": {
#       "city": "Pembroke",
#       "state": "MA"
#     },
#     "insurance": "Medicare/Medicaid"
#   },
#   "encounter": {
#     "date": "2020-03-02",
#     "time": "04:15",
#     "provider_id": "8be741d6-44d0-3412-88dd-4987e1559f0b",
#     "facility_id": "b1ddf812-1fdd-3adf-b1d5-32cc8bd07ebb"
#   },
#   "conditions": [
#     {
#       "code": "U07.1",
#       "description": "Confirmed COVID-19 infection with severe symptoms"
#     },
#     {
#       "code": "R09.02",
#       "description": "Acute hypoxemia requiring intervention"
#     },
#     {
#       "code": "R50.9",
#       "description": "High-grade fever"
#     },
#     {
#       "code": "R11.2",
#       "description": "GI symptoms with risk of dehydration"
#     }
#   ],
#   "medications": [
#     {
#       "code": "Jolivette",
#       "description": "Jolivette (oral contraceptive)"
#     }
#   ],
#   "immunizations": [
#     {
#       "code": "Influenza",
#       "description": "Influenza vaccine",
#       "date": "2020-02-21"
#     },
#     {
#       "code": "Meningococcal",
#       "description": "Meningococcal vaccine",
#       "date": "2020-02-21"
#     }
#   ],
#   "vitals": {
#     "current": {
#       "temperature": {
#         "code": "8310-5",
#         "value": 40.7,
#         "unit": "°C"
#       },
#       "heart_rate": {
#         "code": "8867-4",
#         "value": 98,
#         "unit": "/min"
#       },
#       "blood_pressure": {
#         "systolic": {
#           "code": "8480-6",
#           "value": 120,
#           "unit": "mmHg"
#         },
#         "diastolic": {
#           "code": "8462-4",
#           "value": 89,
#           "unit": "mmHg"
#         }
#       },
#       "respiratory_rate": {
#         "code": "9279-1",
#         "value": 22,
#         "unit": "/min"
#       },
#       "oxygen_saturation": {
#         "code": "59408-5",
#         "value": 78.2,
#         "unit": "%"
#       },
#       "weight": {
#         "code": "29463-7",
#         "value": 45.3,
#         "unit": "kg"
#       }
#     },
#     "baseline": {
#       "date": "2020-02-21",
#       "height": {
#         "code": "8302-2",
#         "value": 149.3,
#         "unit": "cm"
#       },
#       "weight": {
#         "code": "29463-7",
#         "value": 45.3,
#         "unit": "kg"
#       },
#       "bmi": {
#         "code": "39156-5",
#         "value": 20.3,
#         "unit": "kg/m2"
#       },
#       "bmi_percentile": {
#         "code": "59574-4",
#         "value": 47.6,
#         "unit": "%"
#       }
#     }
#   },
#   "laboratory": {
#     "covid19": {
#       "code": "94500-6",
#       "description": "COVID-19 PCR",
#       "result": "POSITIVE"
#     },
#     "respiratory_panel": {
#       "influenza_a": {
#         "code": "LP6464-4",
#         "result": "Negative"
#       },
#       "influenza_b": {
#         "code": "LP6464-4",
#         "result": "Negative"
#       },
#       "rsv": {
#         "code": "LP6464-4",
#         "result": "Negative"
#       },
#       "parainfluenza_1": {
#         "code": "LP6464-4",
#         "result": "Negative"
#       },
#       "parainfluenza_2": {
#         "code": "LP6464-4",
#         "result": "Negative"
#       },
#       "parainfluenza_3": {
#         "code": "LP6464-4",
#         "result": "Negative"
#       },
#       "rhinovirus": {
#         "code": "LP6464-4",
#         "result": "Negative"
#       },
#       "metapneumovirus": {
#         "code": "LP6464-4",
#         "result": "Negative"
#       },
#       "adenovirus": {
#         "code": "LP6464-4",
#         "result": "Negative"
#       }
#     }
#   },
#   "procedures": null
# }
# Validating JSON response against schema...
# Validation successful. Record appended.
# Processing file 3/10: dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/353016ea_a0ff_4154_85bb_1cf8b6cedf20.txt
# Copying file from DBFS to local /tmp/ directory...
# Reading the encounter note file...
# Preparing the prompt for the LLM...
# Invoking LLM for extraction...
# LLM response received. Printing response content for debugging:
# {
#   "demographics": {
#     "name": "Gregorio Auer",
#     "date_of_birth": "11/15/1996",
#     "age": 23,
#     "gender": "Male",
#     "address": {
#       "city": "Boston",
#       "state": "MA"
#     },
#     "insurance": "Medicare/Medicaid"
#   },
#   "encounter": {
#     "date": "March 3, 2020",
#     "time": "00:58-02:19",
#     "provider_id": "6ba172e8-ae6d-3c6c-9f49-38096f9d1e1e",
#     "facility_id": "d78e84ec-30aa-3bba-a33a-f29a3a454662"
#   },
#   "conditions": [
#     {
#       "code": "U07.1",
#       "description": "COVID-19, virus identified"
#     },
#     {
#       "code": "R09.02",
#       "description": "Hypoxemia"
#     },
#     {
#       "code": "R00.1",
#       "description": "Bradycardia, unspecified"
#     },
#     {
#       "code": "J06.9",
#       "description": "Acute upper respiratory infection, unspecified"
#     }
#   ],
#   "medications": null,
#   "immunizations": null,
#   "vitals": {
#     "current": {
#       "temperature": {
#         "code": "8310-5",
#         "value": 38.8,
#         "unit": "°C"
#       },
#       "heart_rate": {
#         "code": "8867-4",
#         "value": 51,
#         "unit": "/min"
#       },
#       "blood_pressure": {
#         "systolic": {
#           "code": "8480-6",
#           "value": 116,
#           "unit": "mmHg"
#         },
#         "diastolic": {
#           "code": "8462-4",
#           "value": 80,
#           "unit": "mmHg"
#         }
#       },
#       "respiratory_rate": {
#         "code": "9279-1",
#         "value": 19,
#         "unit": "/min"
#       },
#       "oxygen_saturation": {
#         "code": "59408-5",
#         "value": 77.6,
#         "unit": "%"
#       },
#       "weight": {
#         "code": "29463-7",
#         "value": 91.2,
#         "unit": "kg"
#       }
#     },
#     "baseline": null
#   },
#   "laboratory": {
#     "covid19": {
#       "code": "94500-6",
#       "description": "SARS-CoV-2 RNA [Presence] in Respiratory specimen by NAA with probe detection",
#       "result": "Positive"
#     },
#     "respiratory_panel": {
#       "influenza_a": {
#         "code": "34416-5",
#         "result": "Negative"
#       },
#       "influenza_b": {
#         "code": "34418-1",
#         "result": "Negative"
#       },
#       "rsv": null,
#       "parainfluenza_1": null,
#       "parainfluenza_2": null,
#       "parainfluenza_3": null,
#       "rhinovirus": null,
#       "metapneumovirus": null,
#       "adenovirus": null
#     }
#   },
#   "procedures": null
# }
# Validating JSON response against schema...
# Validation successful. Record appended.
# Processing file 4/10: dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/ae9efba3_ddc4_43f9_a781_f72019388548.txt
# Copying file from DBFS to local /tmp/ directory...
# Reading the encounter note file...
# Preparing the prompt for the LLM...
# Invoking LLM for extraction...
# LLM response received. Printing response content for debugging:
# {
#   "demographics": {
#     "name": "Jayson Fadel",
#     "date_of_birth": "1992-06-30",
#     "age": 27,
#     "gender": "Male",
#     "address": {
#       "city": "Chicopee",
#       "state": "MA"
#     },
#     "insurance": "Guardian"
#   },
#   "encounter": {
#     "date": "2020-03-11",
#     "time": "10:51",
#     "provider_id": "f59948a6-b07a-3248-9661-60f5924b644b",
#     "facility_id": "5d4b9df1-93ae-3bc9-b680-03249990e558"
#   },
#   "conditions": [
#     {
#       "code": "Not Available",
#       "description": "Hypertension"
#     },
#     {
#       "code": "Not Available",
#       "description": "Viral sinusitis"
#     },
#     {
#       "code": "Not Available",
#       "description": "COVID-19 infection"
#     },
#     {
#       "code": "Not Available",
#       "description": "Hypertensive urgency"
#     },
#     {
#       "code": "Not Available",
#       "description": "Acute hypoxemia"
#     },
#     {
#       "code": "Not Available",
#       "description": "Severe fever"
#     },
#     {
#       "code": "Not Available",
#       "description": "Significant tachycardia"
#     },
#     {
#       "code": "Not Available",
#       "description": "Gastrointestinal symptoms"
#     }
#   ],
#   "medications": [
#     {
#       "code": "Not Available",
#       "description": "amLODIPine/Hydrochlorothiazide/Olmesartan (5/12.5/20 mg) daily"
#     }
#   ],
#   "immunizations": [
#     {
#       "code": "Not Available",
#       "description": "Influenza vaccine",
#       "date": "2019-10-15"
#     }
#   ],
#   "vitals": {
#     "current": {
#       "temperature": {
#         "code": "Not Available",
#         "value": 41.1,
#         "unit": "°C"
#       },
#       "heart_rate": {
#         "code": "Not Available",
#         "value": 187,
#         "unit": "/min"
#       },
#       "blood_pressure": {
#         "systolic": {
#           "code": "Not Available",
#           "value": 187,
#           "unit": "mmHg"
#         },
#         "diastolic": {
#           "code": "Not Available",
#           "value": 96,
#           "unit": "mmHg"
#         }
#       },
#       "respiratory_rate": {
#         "code": "Not Available",
#         "value": 33,
#         "unit": "/min"
#       },
#       "oxygen_saturation": {
#         "code": "Not Available",
#         "value": 88.7,
#         "unit": "%"
#       },
#       "weight": {
#         "code": "Not Available",
#         "value": 68.2,
#         "unit": "kg"
#       }
#     },
#     "baseline": {
#       "date": "2019-10-15",
#       "height": {
#         "code": "Not Available",
#         "value": 165.7,
#         "unit": "cm"
#       },
#       "weight": {
#         "code": "Not Available",
#         "value": 68.2,
#         "unit": "kg"
#       },
#       "bmi": {
#         "code": "Not Available",
#         "value": 24.8,
#         "unit": "kg/m2"
#       },
#       "bmi_percentile": null
#     }
#   },
#   "laboratory": {
#     "covid19": {
#       "code": "Not Available",
#       "description": "COVID-19 PCR",
#       "result": "POSITIVE"
#     },
#     "respiratory_panel": {
#       "influenza_a": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "influenza_b": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "rsv": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "parainfluenza_1": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "parainfluenza_2": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "parainfluenza_3": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "rhinovirus": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "metapneumovirus": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "adenovirus": {
#         "code": "Not Available",
#         "result": "Negative"
#       }
#     }
#   },
#   "procedures": null
# }
# Validating JSON response against schema...
# Validation successful. Record appended.
# Processing file 5/10: dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/28658715_b770_4576_9a81_fbb2282a98ea.txt
# Copying file from DBFS to local /tmp/ directory...
# Reading the encounter note file...
# Preparing the prompt for the LLM...
# Invoking LLM for extraction...
# LLM response received. Printing response content for debugging:
# {
#   "demographics": {
#     "name": "Mrs. Karyn217 Metz686",
#     "date_of_birth": "1991-07-31",
#     "age": 28,
#     "gender": "Female",
#     "address": {
#       "city": "Medfield",
#       "state": "Massachusetts"
#     },
#     "insurance": "Guardian"
#   },
#   "encounter": {
#     "date": "2020-02-29",
#     "time": "04:48",
#     "provider_id": "bc4a66b7-a2ba-3ad3-af08-2975489d8495",
#     "facility_id": "3bd5eda0-16da-3ba5-8500-4dfd6ae118b8"
#   },
#   "conditions": [
#     {
#       "code": "Not Available",
#       "description": "Brain damage - traumatic"
#     },
#     {
#       "code": "Not Available",
#       "description": "History of miscarriage in first trimester"
#     },
#     {
#       "code": "Not Available",
#       "description": "Currently pregnant"
#     },
#     {
#       "code": "Not Available",
#       "description": "Confirmed COVID-19 infection with severe symptoms"
#     },
#     {
#       "code": "Not Available",
#       "description": "Acute hypoxemia"
#     },
#     {
#       "code": "Not Available",
#       "description": "High-grade fever"
#     },
#     {
#       "code": "Not Available",
#       "description": "First trimester pregnancy (high-risk condition with COVID-19)"
#     },
#     {
#       "code": "Not Available",
#       "description": "Myalgia"
#     },
#     {
#       "code": "Not Available",
#       "description": "Arthralgia"
#     },
#     {
#       "code": "Not Available",
#       "description": "Ageusia (loss of taste)"
#     }
#   ],
#   "medications": null,
#   "immunizations": [
#     {
#       "code": "Not Available",
#       "description": "Influenza vaccine",
#       "date": "2019-10-09"
#     }
#   ],
#   "vitals": {
#     "current": {
#       "temperature": {
#         "code": "Not Available",
#         "value": 41.5,
#         "unit": "°C"
#       },
#       "heart_rate": {
#         "code": "Not Available",
#         "value": 84.4,
#         "unit": "/min"
#       },
#       "blood_pressure": {
#         "systolic": {
#           "code": "Not Available",
#           "value": 108,
#           "unit": "mmHg"
#         },
#         "diastolic": {
#           "code": "Not Available",
#           "value": 84,
#           "unit": "mmHg"
#         }
#       },
#       "respiratory_rate": {
#         "code": "Not Available",
#         "value": 27.3,
#         "unit": "/min"
#       },
#       "oxygen_saturation": {
#         "code": "Not Available",
#         "value": 86.7,
#         "unit": "%"
#       },
#       "weight": {
#         "code": "Not Available",
#         "value": 74.0,
#         "unit": "kg"
#       }
#     },
#     "baseline": {
#       "date": "2019-10-09",
#       "height": {
#         "code": "Not Available",
#         "value": 167.3,
#         "unit": "cm"
#       },
#       "weight": {
#         "code": "Not Available",
#         "value": 74.0,
#         "unit": "kg"
#       },
#       "bmi": {
#         "code": "Not Available",
#         "value": 26.4,
#         "unit": "kg/m²"
#       },
#       "bmi_percentile": null
#     }
#   },
#   "laboratory": {
#     "covid19": {
#       "code": "Not Available",
#       "description": "COVID-19 PCR",
#       "result": "POSITIVE"
#     },
#     "respiratory_panel": {
#       "influenza_a": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "influenza_b": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "rsv": null,
#       "parainfluenza_1": null,
#       "parainfluenza_2": null,
#       "parainfluenza_3": null,
#       "rhinovirus": null,
#       "metapneumovirus": null,
#       "adenovirus": null
#     }
#   },
#   "procedures": [
#     {
#       "code": "Not Available",
#       "description": "Complete prenatal panel",
#       "date": "2019-12-03",
#       "reasonCode": "Not Available",
#       "reasonDescription": "Regular prenatal care"
#     },
#     {
#       "code": "Not Available",
#       "description": "Fetal anatomy study",
#       "date": "2020-01-28",
#       "reasonCode": "Not Available",
#       "reasonDescription": "Regular prenatal care"
#     },
#     {
#       "code": "Not Available",
#       "description": "Alpha-fetoprotein test",
#       "date": "2020-01-28",
#       "reasonCode": "Not Available",
#       "reasonDescription": "Regular prenatal care"
#     }
#   ]
# }
# Validating JSON response against schema...
# Validation successful. Record appended.
# Processing file 6/10: dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/b9fd2dd8_181b_494b_ab15_e9f286d668d9.txt
# Copying file from DBFS to local /tmp/ directory...
# Reading the encounter note file...
# Preparing the prompt for the LLM...
# Invoking LLM for extraction...
# LLM response received. Printing response content for debugging:
# {
#   "demographics": {
#     "name": "Mr. Milo271 Feil794",
#     "date_of_birth": "12/12/1983",
#     "age": 36,
#     "gender": "Male",
#     "address": {
#       "city": "Somerville",
#       "state": "Massachusetts"
#     },
#     "insurance": "Guardian"
#   },
#   "encounter": {
#     "date": "February 25, 2020",
#     "time": "15:39",
#     "provider_id": "046c4fac-2680-391a-ba36-eeaec6eed0c5",
#     "facility_id": "e002090d-4e92-300e-b41e-7d1f21dee4c6"
#   },
#   "conditions": [
#     {
#       "code": "U07.1",
#       "description": "Confirmed COVID-19 infection"
#     },
#     {
#       "code": "R09.02",
#       "description": "Acute hypoxemia"
#     },
#     {
#       "code": "R50.9",
#       "description": "Fever"
#     },
#     {
#       "code": "M79.1",
#       "description": "Myalgia"
#     },
#     {
#       "code": "M25.5",
#       "description": "Arthralgia"
#     },
#     {
#       "code": "R43.8",
#       "description": "Ageusia"
#     }
#   ],
#   "medications": null,
#   "immunizations": null,
#   "vitals": {
#     "current": {
#       "temperature": {
#         "code": "8310-5",
#         "value": 39.9,
#         "unit": "°C"
#       },
#       "heart_rate": {
#         "code": "8867-4",
#         "value": 82.1,
#         "unit": "/min"
#       },
#       "blood_pressure": {
#         "systolic": {
#           "code": "8480-6",
#           "value": 122,
#           "unit": "mmHg"
#         },
#         "diastolic": {
#           "code": "8462-4",
#           "value": 80,
#           "unit": "mmHg"
#         }
#       },
#       "respiratory_rate": {
#         "code": "9279-1",
#         "value": 31.5,
#         "unit": "/min"
#       },
#       "oxygen_saturation": {
#         "code": "59408-5",
#         "value": 89.0,
#         "unit": "%"
#       },
#       "weight": {
#         "code": "29463-7",
#         "value": 112.7,
#         "unit": "kg"
#       }
#     },
#     "baseline": null
#   },
#   "laboratory": {
#     "covid19": {
#       "code": "94500-6",
#       "description": "SARS-CoV-2 RNA",
#       "result": "DETECTED"
#     },
#     "respiratory_panel": {
#       "influenza_a": {
#         "code": "LP14239-5",
#         "result": "Negative"
#       },
#       "influenza_b": {
#         "code": "LP14240-3",
#         "result": "Negative"
#       },
#       "rsv": null,
#       "parainfluenza_1": null,
#       "parainfluenza_2": null,
#       "parainfluenza_3": null,
#       "rhinovirus": null,
#       "metapneumovirus": null,
#       "adenovirus": null
#     }
#   },
#   "procedures": null
# }
# Validating JSON response against schema...
# Validation successful. Record appended.
# Processing file 7/10: dbfs:/FileStore/shared_uploads/ktorres2@hawaii.edu/d22592ac_552f_4ecd_a63d_7663d77ce9ba.txt
# Copying file from DBFS to local /tmp/ directory...
# Reading the encounter note file...
# Preparing the prompt for the LLM...
# Invoking LLM for extraction...
# LLM response received. Printing response content for debugging:
# {
#   "demographics": {
#     "name": "Mr. José Eduardo181 Gómez206",
#     "date_of_birth": "6/22/1989",
#     "age": 30,
#     "gender": "Male",
#     "address": {
#       "city": "Chicopee",
#       "state": "Massachusetts"
#     },
#     "insurance": "Guardian"
#   },
#   "encounter": {
#     "date": "March 7, 2020",
#     "time": "12:56",
#     "provider_id": "f59948a6-b07a-3248-9661-60f5924b644b",
#     "facility_id": "5d4b9df1-93ae-3bc9-b680-03249990e558"
#   },
#   "conditions": [
#     {
#       "code": "Not Available",
#       "description": "Obesity"
#     },
#     {
#       "code": "Not Available",
#       "description": "Prediabetes"
#     },
#     {
#       "code": "Not Available",
#       "description": "Confirmed COVID-19 infection with severe symptoms"
#     },
#     {
#       "code": "Not Available",
#       "description": "Acute hypoxemia"
#     },
#     {
#       "code": "Not Available",
#       "description": "Extremely high-grade fever"
#     }
#   ],
#   "medications": [
#     {
#       "code": "Not Available",
#       "description": "Meperidine Hydrochloride 50 MG"
#     },
#     {
#       "code": "Not Available",
#       "description": "Acetaminophen 325 MG"
#     }
#   ],
#   "immunizations": null,
#   "vitals": {
#     "current": {
#       "temperature": {
#         "code": "Not Available",
#         "value": 42.0,
#         "unit": "°C"
#       },
#       "heart_rate": {
#         "code": "Not Available",
#         "value": 87.9,
#         "unit": "/min"
#       },
#       "blood_pressure": {
#         "systolic": {
#           "code": "Not Available",
#           "value": 113,
#           "unit": "mmHg"
#         },
#         "diastolic": {
#           "code": "Not Available",
#           "value": 83,
#           "unit": "mmHg"
#         }
#       },
#       "respiratory_rate": {
#         "code": "Not Available",
#         "value": 20.9,
#         "unit": "/min"
#       },
#       "oxygen_saturation": {
#         "code": "Not Available",
#         "value": 83.5,
#         "unit": "%"
#       },
#       "weight": {
#         "code": "Not Available",
#         "value": 94.7,
#         "unit": "kg"
#       }
#     },
#     "baseline": null
#   },
#   "laboratory": {
#     "covid19": {
#       "code": "Not Available",
#       "description": "COVID-19 PCR",
#       "result": "POSITIVE"
#     },
#     "respiratory_panel": {
#       "influenza_a": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "influenza_b": {
#         "code": "Not Available",
#         "result": "Negative"
#       },
#       "rsv": null,
#       "parainfluenza_1": null,
#       "parainfluenza_2": null,
#       "parainfluenza_3": null,
#       "rhinovirus": null,
#       "metapneumovirus": null,
#       "adenovirus": null
#     }
#   },
#   "procedures": [
#     {
#       "code": "Not Available",
#       "description": "Clavicle X-ray",
#       "date": "9/13/2019",
#       "reasonCode": "Not Available",
#       "reasonDescription": "Clavicle fracture"
#     },
#     {
#       "co
#
# *** WARNING: max output size exceeded, skipping output. ***
#
#                                                                                                                                                                                                       |{{Springfield, Massachusetts}, 15, 1/16/2005, Male, Guardian, Jeffrey Greenfelder}      |{March 2, 2020, 5103c940-0c08-392f-95cd-446e0cea042a, e2c226c2-3e1e-3d0b-b997-ce9544c10528, 15:45}      |[{Not Available, 2/23/2020, Influenza vaccine}]                                                   |{{Not Available, SARS-CoV-2 RNA, Not detected}, {{Not Available, Negative}, {Not Available, Negative}, {Not Available, Negative}, {Not Available, Negative}, {Not Available, Negative}, {Not Available, Negative}, {Not Available, Negative}, {Not Available, Negative}, {Not Available, Negative}}}|NULL                                                                                                                |NULL                                                                                                                                                                                                                                                                               |{{{Not Available, kg/m², 33.8}, {Not Available, percentile, 99.1}, 2/23/2020, {Not Available, cm, 155.0}, {Not Available, kg, 81.2}}, {{{Not Available, mmHg, 73.0}, {Not Available, mmHg, 120.0}}, {Not Available, /min, 131.1}, {Not Available, %, 75.8}, {Not Available, /min, 27.6}, {8310-5, °C, 39.3}, {Not Available, kg, 81.2}}}|
                                   |NULL                                                                                                                                                                                                                                                                               |{{{Not Available, kg/m2, 24.8}, NULL, 2019-10-15, {Not Available, cm, 165.7}, {Not Available, kg, 68.2}}, {{{Not Available, mmHg, 96.0}, {Not Available, mmHg, 187.0}}, {Not Available, /min, 187.0}, {Not Available, %, 88.7}, {Not Available, /min, 33.0}, {8310-5, °C, 41.1}, {Not Available, kg, 68.2}}}                            |
# |[{Not Available, Brain damage - traumatic}, {Not Available, History of miscarriage in first trimester}, {Not Available, Currently pregnant}, {Not Available, Confirmed COVID-19 infection with severe symptoms}, {Not Available, Acute hypoxemia}, {Not Available, High-grade fever}, {Not Available, First trimester pregnancy (high-risk condition with COVID-19)}, {Not Available, Myalgia}, {Not Available, Arthralgia}, {Not Available, Ageusia (loss of taste)}]|{{Medfield, Massachusetts}, 28, 1991-07-31, Female, Guardian, Mrs. Karyn217 Metz686}    |{2020-02-29, 3bd5eda0-16da-3ba5-8500-4dfd6ae118b8, bc4a66b7-a2ba-3ad3-af08-2975489d8495, 04:48}         |[{Not Available, 2019-10-09, Influenza vaccine}]                                                  |{{Not Available, COVID-19 PCR, POSITIVE}, {NULL, {Not Available, Negative}, {Not Available, Negative}, NULL, NULL, NULL, NULL, NULL, NULL}}                                                                                                                                                         |NULL                                                                                                                |[{Not Available, 2019-12-03, Complete prenatal panel, Not Available, Regular prenatal care}, {Not Available, 2020-01-28, Fetal anatomy study, Not Available, Regular prenatal care}, {Not Available, 2020-01-28, Alpha-fetoprotein test, Not Available, Regular prenatal care}]    |{{{Not Available, kg/m², 26.4}, NULL, 2019-10-09, {Not Available, cm, 167.3}, {Not Available, kg, 74.0}}, {{{Not Available, mmHg, 84.0}, {Not Available, mmHg, 108.0}}, {Not Available, /min, 84.4}, {Not Available, %, 86.7}, {Not Available, /min, 27.3}, {8310-5, °C, 41.5}, {Not Available, kg, 74.0}}}                             |
# |[{U07.1, Confirmed COVID-19 infection}, {R09.02, Acute hypoxemia}, {R50.9, Fever}, {M79.1, Myalgia}, {M25.5, Arthralgia}, {R43.8, Ageusia}]                                                                                                                                                                                                                                                                                                                           |{{Somerville, Massachusetts}, 36, 12/12/1983, Male, Guardian, Mr. Milo271 Feil794}      |{February 25, 2020, e002090d-4e92-300e-b41e-7d1f21dee4c6, 046c4fac-2680-391a-ba36-eeaec6eed0c5, 15:39}  |NULL                                                                                              |{{94500-6, SARS-CoV-2 RNA, DETECTED}, {NULL, {LP14239-5, Negative}, {LP14240-3, Negative}, NULL, NULL, NULL, NULL, NULL, NULL}}                                                                                                                                                                     |NULL                                                                                                                |NULL                                                                                                                                                                                                                                                                               |{NULL, {{{8462-4, mmHg, 80.0}, {8480-6, mmHg, 122.0}}, {8867-4, /min, 82.1}, {59408-5, %, 89.0}, {9279-1, /min, 31.5}, {8310-5, °C, 39.9}, {29463-7, kg, 112.7}}}                                                                                                                                                                       |
# |[{Not Available, Obesity}, {Not Available, Prediabetes}, {Not Available, Confirmed COVID-19 infection with severe symptoms}, {Not Available, Acute hypoxemia}, {Not Available, Extremely high-grade fever}]                                                                                                                                                                                                                                                           |{{Chicopee, Massachusetts}, 30, 6/22/1989, Male, Guardian, Mr. José Eduardo181 Gómez206}|{March 7, 2020, 5d4b9df1-93ae-3bc9-b680-03249990e558, f59948a6-b07a-3248-9661-60f5924b644b, 12:56}      |NULL                                                                                              |{{Not Available, COVID-19 PCR, POSITIVE}, {NULL, {Not Available, Negative}, {Not Available, Negative}, NULL, NULL, NULL, NULL, NULL, NULL}}                                                                                                                                                         |[{Not Available, Meperidine Hydrochloride 50 MG}, {Not Available, Acetaminophen 325 MG}]                            |[{Not Available, 9/13/2019, Clavicle X-ray, Not Available, Clavicle fracture}, {Not Available, 9/13/2019, Admission to orthopedic department, Not Available, Clavicle fracture}]                                                                                                   |{NULL, {{{Not Available, mmHg, 83.0}, {Not Available, mmHg, 113.0}}, {Not Available, /min, 87.9}, {Not Available, %, 83.5}, {Not Available, /min, 20.9}, {8310-5, °C, 42.0}, {Not Available, kg, 94.7}}}                                                                                                                                |
# |[{Not Available, Confirmed COVID-19 infection with severe symptoms}, {Not Available, Acute hypoxemia}, {Not Available, High fever}, {Not Available, Tachycardia and tachypnea}]                                                                                                                                                                                                                                                                                       |{{Springfield, MA}, 2, 2017-08-24, Male, Self-Pay, Jacinto Kris}                        |{2020-03-02, fd328395-ab1d-35c6-a2d0-d05a9a79cf11, 9c875a09-93e0-39aa-9260-ad264bbdd3fe, 01:02}         |[{Not Available, 2019-08-01, Influenza vaccine}, {Not Available, 2020-01-30, Hepatitis A vaccine}]|{{Not Available, COVID-19 PCR, POSITIVE}, {{Not Available, Negative}, {Not Available, Negative}, {Not Available, Negative}, {Not Available, Negative}, {Not Available, Negative}, {Not Available, Negative}, {Not Available, Negative}, {Not Available, Negative}, {Not Available, Negative}}}      |NULL                                                                                                                |NULL                                                                                                                                                                                                                                                                               |{{{Not Available, kg/m2, 18.0}, {Not Available, percentile, 88.0}, 2020-01-30, {Not Available, cm, 86.3}, {Not Available, kg, 13.4}}, {{{Not Available, mmHg, 75.0}, {Not Available, mmHg, 130.0}}, {Not Available, min, 164.0}, {Not Available, %, 86.2}, {Not Available, min, 33.0}, {8310-5, °C, 39.7}, {Not Available, kg, 13.5}}}  |
# |[{Not Available, Pulmonary emphysema}, {Not Available, Hypertension}, {Not Available, Multiple allergies}]                                                                                                                                                                                                                                                                                                                                                            |{{Boston, MA}, 37, 1982-09-29, Female, Medicare/Medicaid, Ms. Brown}                    |{2020-03-13, Not Available, d76028b8-d23f-346e-abd0-65995aec66c8, 16:12}                                |[{Not Available, 2020-03-11, Influenza vaccine}]                                                  |{{Not Available, COVID-19 PCR, POSITIVE}, {{Not Available, Negative}, {Not Available, Negative}, {Not Available, Negative}, {Not Available, Negative}, {Not Available, Negative}, {Not Available, Negative}, {Not Available, Negative}, {Not Available, Negative}, {Not Available, Negative}}}      |[{Not Available, Hydrochlorothiazide 12.5 MG daily}, {Not Available, Fluticasone/Salmeterol 250/50 mcg inhaler BID}]|NULL                                                                                                                                                                                                                                                                               |{NULL, {{{Not Available, mmHg, 78.0}, {Not Available, mmHg, 106.0}}, {Not Available, min, 179.0}, {Not Available, %, 83.6}, {Not Available, min, 24.0}, {8310-5, °C, 40.6}, {Not Available, kg, 59.9}}}                                                                                                                                 |
# |[{Not Available, Confirmed COVID-19 infection with severe symptoms}, {Not Available, Early pregnancy (first trimester)}, {Not Available, Acute hypoxemia requiring intervention}, {Not Available, Significant tachycardia}, {Not Available, High-grade fever requiring management}]                                                                                                                                                                                   |{{Needham, Massachusetts}, 30, 1989-07-05, Female, Self, Mrs. Leann224 Deckow585}       |{2020-03-08, 3d10019f-c88e-3de5-9916-6107b9c0263d, 6b47028d-5118-3ace-91cc-a37789612e24, 21:03}         |NULL                                                                                              |{{Not Available, COVID-19 PCR, POSITIVE}, {NULL, {Not Available, Negative}, {Not Available, Negative}, NULL, NULL, NULL, NULL, NULL, NULL}}                                                                                                                                                         |NULL                                                                                                                |[{Not Available, 2020-03-11, Complete prenatal panel, Not Available, Not Available}, {Not Available, 2020-03-11, Ultrasound scan for fetal viability, Not Available, Not Available}, {Not Available, 2020-03-11, Standard pregnancy screening tests, Not Available, Not Available}]|{NULL, {{{Not Available, mmHg, 84.0}, {Not Available, mmHg, 104.0}}, {Not Available, /min, 151.0}, {Not Available, %, 88.9}, {Not Available, /min, 12.3}, {8310-5, °C, 40.1}, {Not Available, kg, 69.6}}}                                                                                                                               |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# root
#  |-- conditions: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- code: string (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |-- demographics: struct (nullable = true)
#  |    |-- address: struct (nullable = true)
#  |    |    |-- city: string (nullable = true)
#  |    |    |-- state: string (nullable = true)
#  |    |-- age: long (nullable = true)
#  |    |-- date_of_birth: string (nullable = true)
#  |    |-- gender: string (nullable = true)
#  |    |-- insurance: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |-- encounter: struct (nullable = true)
#  |    |-- date: string (nullable = true)
#  |    |-- facility_id: string (nullable = true)
#  |    |-- provider_id: string (nullable = true)
#  |    |-- time: string (nullable = true)
#  |-- immunizations: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- code: string (nullable = true)
#  |    |    |-- date: string (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |-- laboratory: struct (nullable = true)
#  |    |-- covid19: struct (nullable = true)
#  |    |    |-- code: string (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |    |    |-- result: string (nullable = true)
#  |    |-- respiratory_panel: struct (nullable = true)
#  |    |    |-- adenovirus: struct (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- result: string (nullable = true)
#  |    |    |-- influenza_a: struct (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- result: string (nullable = true)
#  |    |    |-- influenza_b: struct (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- result: string (nullable = true)
#  |    |    |-- metapneumovirus: struct (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- result: string (nullable = true)
#  |    |    |-- parainfluenza_1: struct (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- result: string (nullable = true)
#  |    |    |-- parainfluenza_2: struct (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- result: string (nullable = true)
#  |    |    |-- parainfluenza_3: struct (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- result: string (nullable = true)
#  |    |    |-- rhinovirus: struct (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- result: string (nullable = true)
#  |    |    |-- rsv: struct (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- result: string (nullable = true)
#  |-- medications: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- code: string (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |-- procedures: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- code: string (nullable = true)
#  |    |    |-- date: string (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |    |    |-- reasonCode: string (nullable = true)
#  |    |    |-- reasonDescription: string (nullable = true)
#  |-- vitals: struct (nullable = true)
#  |    |-- baseline: struct (nullable = true)
#  |    |    |-- bmi: struct (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- unit: string (nullable = true)
#  |    |    |    |-- value: double (nullable = true)
#  |    |    |-- bmi_percentile: struct (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- unit: string (nullable = true)
#  |    |    |    |-- value: double (nullable = true)
#  |    |    |-- date: string (nullable = true)
#  |    |    |-- height: struct (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- unit: string (nullable = true)
#  |    |    |    |-- value: double (nullable = true)
#  |    |    |-- weight: struct (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- unit: string (nullable = true)
#  |    |    |    |-- value: double (nullable = true)
#  |    |-- current: struct (nullable = true)
#  |    |    |-- blood_pressure: struct (nullable = true)
#  |    |    |    |-- diastolic: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- unit: string (nullable = true)
#  |    |    |    |    |-- value: double (nullable = true)
#  |    |    |    |-- systolic: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- unit: string (nullable = true)
#  |    |    |    |    |-- value: double (nullable = true)
#  |    |    |-- heart_rate: struct (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- unit: string (nullable = true)
#  |    |    |    |-- value: double (nullable = true)
#  |    |    |-- oxygen_saturation: struct (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- unit: string (nullable = true)
#  |    |    |    |-- value: double (nullable = true)
#  |    |    |-- respiratory_rate: struct (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- unit: string (nullable = true)
#  |    |    |    |-- value: double (nullable = true)
#  |    |    |-- temperature: struct (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- unit: string (nullable = true)
#  |    |    |    |-- value: double (nullable = true)
#  |    |    |-- weight: struct (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- unit: string (nullable = true)
#  |    |    |    |-- value: double (nullable = true)
#
# Processing complete.
